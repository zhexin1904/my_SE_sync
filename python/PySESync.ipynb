# %% [markdown]
# # PySESync: SE-Sync Python bindings 🐍

# %% [markdown]
# This notebook demonstrates the use of SE-Sync's Python bindings

# %%
import sys
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import collections as mc
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Line3DCollection
import matplotlib.animation as animation

# %matplotlib notebook

# %% [markdown]
# Import the SE-Sync Python library built using pybind

# %%
import PySESync

# %% [markdown]
# Load in some data from a .g2o file

# %%
# filename = "../data/intel.g2o"
filename = "../data/parking-garage.g2o"


measurements, num_poses = PySESync.read_g2o_file(filename)

d = measurements[0].R.shape[0]

print("Loaded %d measurements between %d %d-dimensional poses from file %s" % (len(measurements), num_poses, d, filename))
# Out:
# Loaded 6275 measurements between 1661 3-dimensional poses from file ../data/parking-garage.g2o

# %% [markdown]
# ### Run SE-Sync!

# %% [markdown]
# Set SE-Sync options

# %%
opts = PySESync.SESyncOpts()
opts.num_threads = 4
opts.verbose=True

opts.r0 = d
opts.formulation = PySESync.Formulation.Explicit    # Options are Simplified or Explicit
opts.initialization = PySESync.Initialization.Random   # Options are Chordal or Random

# Termination criteria
opts.rel_func_decrease_tol = 1e-6
opts.min_eig_num_tol = 1e-3
opts.max_time = 900

# We will record the sequence of iterates generated by the SE-Sync algorithm as it runs,
# in order to generate an animation of the solution process
opts.log_iterates = True


# Save the solution animation to a video file?
save_animation = False

# %% [markdown]
# Run SE-Sync!

# %%
result = PySESync.SESync(measurements, opts)
# Out:
# Constructing SE-Sync problem instance ... elapsed computation time: 0.213 seconds
#
# ========= SE-Sync ==========
#
# ALGORITHM SETTINGS:
#
# SE-Sync settings:
#  SE-Sync problem formulation: Explicit
#  Initial level of Riemannian staircase: 3
#  Maximum level of Riemannian staircase: 10
#  Tolerance for accepting an eigenvalue as numerically nonnegative in optimality verification: 0.001
#  LOBPCG block size: 4
#  LOBPCG preconditioner maximum fill factor: 3
#  LOBPCG preconditioner drop tolerance: 0.001
#  Maximum number of LOBPCG iterations for escape direction computation: 100
#  Initialization method: random
#  Logging entire sequence of Riemannian Staircase iterates
#  Running SE-Sync with 4 threads
#
# Riemannian trust-region settings:
#  Stopping tolerance for norm of Riemannian gradient: 0.01
#  Stopping tolerance for norm of preconditioned Riemannian gradient: 0.0001
#  Stopping tolerance for relative function decrease: 1e-06
#  Stopping tolerance for the norm of an accepted update step: 0.001
#  Maximum number of trust-region iterations: 1000
#  Maximum number of truncated conjugate gradient iterations per outer iteration: 10000
#  STPCG fractional gradient tolerance (kappa): 0.1
#  STPCG target q-superlinear convergence rate (1 + theta): 1.5
#  Preconditioning the truncated conjugate gradient method using regularized Cholesky preconditioner with maximum condition number 1e+06
#
# INITIALIZATION:
#  Sampling a random initialization ...
#  SE-Sync initialization finished; elapsed time: 0.001 seconds
#
# Initial objective value: 211598
#
#
# ====== RIEMANNIAN STAIRCASE (level r = 3) ======
#
# Truncated-Newton trust-region optimization:
#
# Iter:    0, time: 0.000e+00, f:  2.116e+05, |g|: 1.968e+03, |M^{-1}g|: 6.664e+04, Delta: 1.000e+00, inner iters:     0, |h|: 2.505e+01, |h|_M: 1.000e+00, df:  2.633e+03, rho:  9.984e-01. Step accepted
# Iter:    1, time: 4.000e-03, f:  2.090e+05, |g|: 1.965e+03, |M^{-1}g|: 6.386e+04, Delta: 2.500e+00, inner iters:     0, |h|: 6.070e+01, |h|_M: 2.500e+00, df:  6.635e+03, rho:  9.642e-01. Step accepted
# Iter:    2, time: 9.000e-03, f:  2.023e+05, |g|: 1.996e+03, |M^{-1}g|: 6.633e+04, Delta: 6.250e+00, inner iters:     0, |h|: 1.414e+02, |h|_M: 6.250e+00, df:  1.103e+04, rho:  3.455e-01. Step accepted
# Iter:    3, time: 1.300e-02, f:  1.913e+05, |g|: 2.173e+03, |M^{-1}g|: 4.734e+04, Delta: 6.250e+00, inner iters:     0, |h|: 1.103e+02, |h|_M: 6.250e+00, df:  7.648e+03, rho:  6.390e-01. Step accepted
# Iter:    4, time: 1.700e-02, f:  1.837e+05, |g|: 2.178e+03, |M^{-1}g|: 5.817e+04, Delta: 6.250e+00, inner iters:     1, |h|: 1.193e+02, |h|_M: 6.250e+00, df:  7.586e+03, rho:  7.972e-01. Step accepted
# Iter:    5, time: 2.300e-02, f:  1.761e+05, |g|: 2.226e+03, |M^{-1}g|: 6.360e+04, Delta: 6.250e+00, inner iters:     2, |h|: 1.088e+02, |h|_M: 6.250e+00, df:  6.464e+03, rho:  7.877e-01. Step accepted
# Iter:    6, time: 3.100e-02, f:  1.696e+05, |g|: 2.255e+03, |M^{-1}g|: 6.660e+04, Delta: 6.250e+00, inner iters:     3, |h|: 1.053e+02, |h|_M: 6.250e+00, df:  5.437e+03, rho:  8.428e-01. Step accepted
# Iter:    7, time: 4.000e-02, f:  1.642e+05, |g|: 2.297e+03, |M^{-1}g|: 7.409e+04, Delta: 6.250e+00, inner iters:     3, |h|: 1.009e+02, |h|_M: 6.250e+00, df:  5.282e+03, rho:  7.609e-01. Step accepted
# Iter:    8, time: 5.100e-02, f:  1.589e+05, |g|: 2.356e+03, |M^{-1}g|: 1.052e+05, Delta: 6.250e+00, inner iters:     3, |h|: 1.023e+02, |h|_M: 6.250e+00, df:  6.289e+03, rho:  7.703e-01. Step accepted
# Iter:    9, time: 6.000e-02, f:  1.526e+05, |g|: 2.389e+03, |M^{-1}g|: 5.382e+04, Delta: 6.250e+00, inner iters:     3, |h|: 1.087e+02, |h|_M: 6.250e+00, df:  5.165e+03, rho:  7.917e-01. Step accepted
# Iter:   10, time: 7.300e-02, f:  1.474e+05, |g|: 2.490e+03, |M^{-1}g|: 6.044e+04, Delta: 6.250e+00, inner iters:     4, |h|: 1.051e+02, |h|_M: 6.250e+00, df:  5.515e+03, rho:  7.421e-01. Step accepted
# Iter:   11, time: 8.700e-02, f:  1.419e+05, |g|: 2.558e+03, |M^{-1}g|: 7.206e+04, Delta: 6.250e+00, inner iters:     4, |h|: 1.021e+02, |h|_M: 6.250e+00, df:  5.822e+03, rho:  8.016e-01. Step accepted
# Iter:   12, time: 9.800e-02, f:  1.361e+05, |g|: 2.621e+03, |M^{-1}g|: 5.627e+04, Delta: 6.250e+00, inner iters:     5, |h|: 8.708e+01, |h|_M: 6.250e+00, df:  5.201e+03, rho:  8.133e-01. Step accepted
# Iter:   13, time: 1.100e-01, f:  1.309e+05, |g|: 2.643e+03, |M^{-1}g|: 7.119e+04, Delta: 6.250e+00, inner iters:     5, |h|: 7.236e+01, |h|_M: 6.250e+00, df:  5.948e+03, rho:  8.671e-01. Step accepted
# Iter:   14, time: 1.240e-01, f:  1.249e+05, |g|: 2.622e+03, |M^{-1}g|: 5.357e+04, Delta: 6.250e+00, inner iters:     5, |h|: 7.873e+01, |h|_M: 6.250e+00, df:  5.436e+03, rho:  9.098e-01. Step accepted
# Iter:   15, time: 1.380e-01, f:  1.195e+05, |g|: 2.613e+03, |M^{-1}g|: 4.448e+04, Delta: 1.562e+01, inner iters:     6, |h|: 1.781e+02, |h|_M: 1.562e+01, df:  7.502e+03, rho:  7.629e-01. Step accepted
# Iter:   16, time: 1.530e-01, f:  1.120e+05, |g|: 2.712e+03, |M^{-1}g|: 6.924e+04, Delta: 1.562e+01, inner iters:     9, |h|: 1.816e+02, |h|_M: 1.562e+01, df:  9.601e+03, rho:  7.203e-01. Step accepted
# Iter:   17, time: 1.740e-01, f:  1.024e+05, |g|: 2.684e+03, |M^{-1}g|: 6.743e+04, Delta: 1.562e+01, inner iters:    10, |h|: 2.169e+02, |h|_M: 1.562e+01, df:  9.226e+03, rho:  7.583e-01. Step accepted
# Iter:   18, time: 1.960e-01, f:  9.318e+04, |g|: 2.568e+03, |M^{-1}g|: 7.109e+04, Delta: 1.562e+01, inner iters:    11, |h|: 2.137e+02, |h|_M: 1.562e+01, df:  8.313e+03, rho:  8.611e-01. Step accepted
# Iter:   19, time: 2.200e-01, f:  8.487e+04, |g|: 2.446e+03, |M^{-1}g|: 4.686e+04, Delta: 1.562e+01, inner iters:    11, |h|: 2.038e+02, |h|_M: 1.562e+01, df:  7.604e+03, rho:  8.655e-01. Step accepted
# Iter:   20, time: 2.450e-01, f:  7.726e+04, |g|: 2.388e+03, |M^{-1}g|: 5.352e+04, Delta: 1.562e+01, inner iters:    12, |h|: 1.841e+02, |h|_M: 1.562e+01, df:  7.556e+03, rho:  9.326e-01. Step accepted
# Iter:   21, time: 2.710e-01, f:  6.971e+04, |g|: 2.185e+03, |M^{-1}g|: 3.104e+04, Delta: 3.906e+01, inner iters:    14, |h|: 3.285e+02, |h|_M: 3.906e+01, df:  9.454e+03, rho:  7.387e-01. Step accepted
# Iter:   22, time: 3.020e-01, f:  6.025e+04, |g|: 2.095e+03, |M^{-1}g|: 7.076e+04, Delta: 3.906e+01, inner iters:    19, |h|: 3.072e+02, |h|_M: 3.906e+01, df:  1.142e+04, rho:  6.931e-01. Step accepted
# Iter:   23, time: 3.400e-01, f:  4.883e+04, |g|: 1.808e+03, |M^{-1}g|: 4.631e+04, Delta: 3.906e+01, inner iters:    19, |h|: 4.610e+02, |h|_M: 3.906e+01, df: -4.074e+03, rho: -2.780e-01. Step REJECTED!
# Iter:   24, time: 3.760e-01, f:  4.883e+04, |g|: 1.808e+03, |M^{-1}g|: 4.631e+04, Delta: 9.766e+00, inner iters:    12, |h|: 1.871e+02, |h|_M: 9.766e+00, df:  6.561e+03, rho:  1.006e+00. Step accepted
# Iter:   25, time: 4.000e-01, f:  4.227e+04, |g|: 1.510e+03, |M^{-1}g|: 2.230e+04, Delta: 2.441e+01, inner iters:    14, |h|: 1.740e+02, |h|_M: 2.441e+01, df:  4.480e+03, rho:  8.835e-01. Step accepted
# Iter:   26, time: 4.280e-01, f:  3.779e+04, |g|: 1.365e+03, |M^{-1}g|: 3.230e+04, Delta: 2.441e+01, inner iters:    20, |h|: 1.929e+02, |h|_M: 2.441e+01, df:  5.304e+03, rho:  9.298e-01. Step accepted
# Iter:   27, time: 4.650e-01, f:  3.249e+04, |g|: 1.130e+03, |M^{-1}g|: 2.679e+04, Delta: 6.104e+01, inner iters:    25, |h|: 2.756e+02, |h|_M: 6.104e+01, df:  6.206e+03, rho:  7.222e-01. Step accepted
# Iter:   28, time: 5.120e-01, f:  2.628e+04, |g|: 8.339e+02, |M^{-1}g|: 2.711e+04, Delta: 6.104e+01, inner iters:    34, |h|: 3.604e+02, |h|_M: 6.104e+01, df:  1.642e+03, rho:  2.166e-01. Step accepted
# Iter:   29, time: 5.710e-01, f:  2.464e+04, |g|: 7.690e+02, |M^{-1}g|: 5.427e+04, Delta: 6.104e+01, inner iters:    23, |h|: 5.669e+02, |h|_M: 6.104e+01, df: -2.853e+04, rho: -1.935e+00. Step REJECTED!
# Iter:   30, time: 6.140e-01, f:  2.464e+04, |g|: 7.690e+02, |M^{-1}g|: 5.427e+04, Delta: 1.526e+01, inner iters:    18, |h|: 2.144e+02, |h|_M: 1.526e+01, df:  4.612e+03, rho:  8.150e-01. Step accepted
# Iter:   31, time: 6.500e-01, f:  2.003e+04, |g|: 4.640e+02, |M^{-1}g|: 2.136e+04, Delta: 1.526e+01, inner iters:    23, |h|: 1.424e+02, |h|_M: 1.526e+01, df:  6.642e+02, rho:  3.691e-01. Step accepted
# Iter:   32, time: 6.940e-01, f:  1.937e+04, |g|: 3.975e+02, |M^{-1}g|: 2.328e+04, Delta: 1.526e+01, inner iters:    27, |h|: 1.242e+02, |h|_M: 1.526e+01, df:  1.398e+03, rho:  8.218e-01. Step accepted
# Iter:   33, time: 7.460e-01, f:  1.797e+04, |g|: 2.826e+02, |M^{-1}g|: 1.316e+04, Delta: 1.526e+01, inner iters:    28, |h|: 1.025e+02, |h|_M: 1.526e+01, df:  8.323e+02, rho:  9.553e-01. Step accepted
# Iter:   34, time: 7.970e-01, f:  1.713e+04, |g|: 2.282e+02, |M^{-1}g|: 6.323e+03, Delta: 3.815e+01, inner iters:    34, |h|: 2.503e+02, |h|_M: 3.815e+01, df: -1.217e+03, rho: -9.683e-01. Step REJECTED!
# Iter:   35, time: 8.570e-01, f:  1.713e+04, |g|: 2.282e+02, |M^{-1}g|: 6.323e+03, Delta: 9.537e+00, inner iters:    27, |h|: 7.309e+01, |h|_M: 9.537e+00, df:  4.478e+02, rho:  9.221e-01. Step accepted
# Iter:   36, time: 9.060e-01, f:  1.669e+04, |g|: 1.810e+02, |M^{-1}g|: 8.622e+03, Delta: 2.384e+01, inner iters:    33, |h|: 1.384e+02, |h|_M: 2.384e+01, df:  5.373e+02, rho:  8.247e-01. Step accepted
# Iter:   37, time: 9.620e-01, f:  1.615e+04, |g|: 1.848e+02, |M^{-1}g|: 6.905e+03, Delta: 2.384e+01, inner iters:    42, |h|: 1.654e+02, |h|_M: 2.384e+01, df: -4.411e+02, rho: -6.598e-01. Step REJECTED!
# Iter:   38, time: 1.033e+00, f:  1.615e+04, |g|: 1.848e+02, |M^{-1}g|: 6.905e+03, Delta: 5.960e+00, inner iters:    28, |h|: 4.681e+01, |h|_M: 5.960e+00, df:  3.296e+02, rho:  9.683e-01. Step accepted
# Iter:   39, time: 1.082e+00, f:  1.582e+04, |g|: 9.430e+01, |M^{-1}g|: 1.404e+03, Delta: 1.490e+01, inner iters:    31, |h|: 1.108e+02, |h|_M: 1.490e+01, df:  1.952e+02, rho:  8.835e-01. Step accepted
# Iter:   40, time: 1.135e+00, f:  1.562e+04, |g|: 1.283e+02, |M^{-1}g|: 2.004e+04, Delta: 1.490e+01, inner iters:    24, |h|: 3.000e+01, |h|_M: 3.092e+00, df:  1.392e+02, rho:  1.004e+00. Step accepted
# Iter:   41, time: 1.176e+00, f:  1.549e+04, |g|: 6.362e+01, |M^{-1}g|: 1.497e+03, Delta: 1.490e+01, inner iters:    29, |h|: 1.253e+02, |h|_M: 1.490e+01, df:  1.276e+02, rho:  8.325e-01. Step accepted
# Iter:   42, time: 1.226e+00, f:  1.536e+04, |g|: 9.673e+01, |M^{-1}g|: 2.872e+03, Delta: 1.490e+01, inner iters:    50, |h|: 1.190e+02, |h|_M: 1.490e+01, df:  1.682e+02, rho:  8.160e-01. Step accepted
# Iter:   43, time: 1.311e+00, f:  1.519e+04, |g|: 7.880e+01, |M^{-1}g|: 3.563e+03, Delta: 1.490e+01, inner iters:    63, |h|: 1.416e+02, |h|_M: 1.490e+01, df:  1.265e+02, rho:  7.775e-01. Step accepted
# Iter:   44, time: 1.419e+00, f:  1.506e+04, |g|: 7.508e+01, |M^{-1}g|: 3.901e+03, Delta: 1.490e+01, inner iters:    76, |h|: 1.503e+02, |h|_M: 1.490e+01, df:  8.520e+01, rho:  6.620e-01. Step accepted
# Iter:   45, time: 1.547e+00, f:  1.498e+04, |g|: 6.042e+01, |M^{-1}g|: 4.216e+03, Delta: 1.490e+01, inner iters:    96, |h|: 1.700e+02, |h|_M: 1.490e+01, df:  1.136e+02, rho:  1.018e+00. Step accepted
# Iter:   46, time: 1.706e+00, f:  1.486e+04, |g|: 4.470e+01, |M^{-1}g|: 3.314e+03, Delta: 3.725e+01, inner iters:   123, |h|: 3.697e+02, |h|_M: 3.725e+01, df: -1.018e+03, rho: -9.189e+00. Step REJECTED!
# Iter:   47, time: 1.905e+00, f:  1.486e+04, |g|: 4.470e+01, |M^{-1}g|: 3.314e+03, Delta: 9.313e+00, inner iters:    78, |h|: 1.027e+02, |h|_M: 9.313e+00, df:  4.721e+01, rho:  9.351e-01. Step accepted
# Iter:   48, time: 2.031e+00, f:  1.482e+04, |g|: 3.603e+01, |M^{-1}g|: 1.793e+03, Delta: 2.328e+01, inner iters:   119, |h|: 2.684e+02, |h|_M: 2.328e+01, df: -5.447e+01, rho: -7.646e-01. Step REJECTED!
# Iter:   49, time: 2.227e+00, f:  1.482e+04, |g|: 3.603e+01, |M^{-1}g|: 1.793e+03, Delta: 5.821e+00, inner iters:    58, |h|: 6.644e+01, |h|_M: 5.821e+00, df:  3.494e+01, rho:  1.057e+00. Step accepted
# Iter:   50, time: 2.322e+00, f:  1.478e+04, |g|: 2.682e+01, |M^{-1}g|: 8.199e+02, Delta: 1.455e+01, inner iters:    77, |h|: 1.921e+02, |h|_M: 1.455e+01, df: -1.935e+00, rho: -4.778e-02. Step REJECTED!
# Iter:   51, time: 2.450e+00, f:  1.478e+04, |g|: 2.682e+01, |M^{-1}g|: 8.199e+02, Delta: 3.638e+00, inner iters:    43, |h|: 4.434e+01, |h|_M: 3.638e+00, df:  1.496e+01, rho:  1.024e+00. Step accepted
# Iter:   52, time: 2.523e+00, f:  1.477e+04, |g|: 2.442e+01, |M^{-1}g|: 5.846e+02, Delta: 9.095e+00, inner iters:    56, |h|: 1.221e+02, |h|_M: 9.095e+00, df:  1.658e+01, rho:  6.539e-01. Step accepted
# Iter:   53, time: 2.618e+00, f:  1.475e+04, |g|: 4.498e+01, |M^{-1}g|: 2.328e+03, Delta: 9.095e+00, inner iters:    83, |h|: 9.611e+01, |h|_M: 9.095e+00, df:  3.144e+01, rho:  7.784e-01. Step accepted
# Iter:   54, time: 2.755e+00, f:  1.472e+04, |g|: 3.321e+01, |M^{-1}g|: 1.037e+03, Delta: 9.095e+00, inner iters:    96, |h|: 1.125e+02, |h|_M: 9.095e+00, df:  3.437e+01, rho:  9.539e-01. Step accepted
# Iter:   55, time: 2.914e+00, f:  1.468e+04, |g|: 2.972e+01, |M^{-1}g|: 2.262e+03, Delta: 2.274e+01, inner iters:   201, |h|: 2.060e+02, |h|_M: 2.274e+01, df: -3.023e+01, rho: -8.058e-01. Step REJECTED!
# Iter:   56, time: 3.235e+00, f:  1.468e+04, |g|: 2.972e+01, |M^{-1}g|: 2.262e+03, Delta: 5.684e+00, inner iters:    87, |h|: 5.108e+01, |h|_M: 5.684e+00, df:  2.051e+01, rho:  1.016e+00. Step accepted
# Iter:   57, time: 3.390e+00, f:  1.466e+04, |g|: 1.764e+01, |M^{-1}g|: 5.916e+02, Delta: 1.421e+01, inner iters:   108, |h|: 1.780e+02, |h|_M: 1.421e+01, df: -6.762e+01, rho: -2.940e+00. Step REJECTED!
# Iter:   58, time: 3.583e+00, f:  1.466e+04, |g|: 1.764e+01, |M^{-1}g|: 5.916e+02, Delta: 3.553e+00, inner iters:    60, |h|: 4.830e+01, |h|_M: 3.553e+00, df:  9.469e+00, rho:  9.846e-01. Step accepted
# Iter:   59, time: 3.695e+00, f:  1.465e+04, |g|: 1.486e+01, |M^{-1}g|: 6.670e+02, Delta: 8.882e+00, inner iters:    81, |h|: 9.528e+01, |h|_M: 8.882e+00, df:  8.545e+00, rho:  6.263e-01. Step accepted
# Iter:   60, time: 3.841e+00, f:  1.465e+04, |g|: 2.964e+01, |M^{-1}g|: 1.409e+03, Delta: 8.882e+00, inner iters:   119, |h|: 8.621e+01, |h|_M: 8.882e+00, df:  1.828e+01, rho:  9.210e-01. Step accepted
# Iter:   61, time: 4.038e+00, f:  1.463e+04, |g|: 2.518e+01, |M^{-1}g|: 1.103e+03, Delta: 2.220e+01, inner iters:    99, |h|: 2.857e+02, |h|_M: 2.220e+01, df: -1.060e+03, rho: -3.813e+01. Step REJECTED!
# Iter:   62, time: 4.200e+00, f:  1.463e+04, |g|: 2.518e+01, |M^{-1}g|: 1.103e+03, Delta: 5.551e+00, inner iters:    88, |h|: 7.586e+01, |h|_M: 5.551e+00, df:  5.492e-01, rho:  4.658e-02. Step REJECTED!
# Iter:   63, time: 4.349e+00, f:  1.463e+04, |g|: 2.518e+01, |M^{-1}g|: 1.103e+03, Delta: 1.388e+00, inner iters:    44, |h|: 1.871e+01, |h|_M: 1.388e+00, df:  7.197e+00, rho:  1.027e+00. Step accepted
# Iter:   64, time: 4.428e+00, f:  1.462e+04, |g|: 9.483e+00, |M^{-1}g|: 2.306e+02, Delta: 3.469e+00, inner iters:    53, |h|: 5.007e+01, |h|_M: 3.469e+00, df:  3.341e+00, rho:  8.291e-01. Step accepted
# Iter:   65, time: 4.517e+00, f:  1.462e+04, |g|: 1.286e+01, |M^{-1}g|: 6.969e+02, Delta: 3.469e+00, inner iters:    75, |h|: 4.199e+01, |h|_M: 3.469e+00, df:  5.374e+00, rho:  1.043e+00. Step accepted
# Iter:   66, time: 4.643e+00, f:  1.461e+04, |g|: 1.069e+01, |M^{-1}g|: 2.821e+02, Delta: 8.674e+00, inner iters:    99, |h|: 1.212e+02, |h|_M: 8.674e+00, df: -4.413e-01, rho: -5.673e-02. Step REJECTED!
# Iter:   67, time: 4.804e+00, f:  1.461e+04, |g|: 1.069e+01, |M^{-1}g|: 2.821e+02, Delta: 2.168e+00, inner iters:    60, |h|: 2.706e+01, |h|_M: 2.168e+00, df:  2.939e+00, rho:  1.019e+00. Step accepted
# Iter:   68, time: 4.910e+00, f:  1.461e+04, |g|: 8.162e+00, |M^{-1}g|: 1.895e+02, Delta: 5.421e+00, inner iters:    76, |h|: 7.213e+01, |h|_M: 5.421e+00, df:  4.002e+00, rho:  8.777e-01. Step accepted
# Iter:   69, time: 5.037e+00, f:  1.461e+04, |g|: 1.435e+01, |M^{-1}g|: 5.831e+02, Delta: 5.421e+00, inner iters:   112, |h|: 7.369e+01, |h|_M: 5.421e+00, df:  6.570e+00, rho:  1.053e+00. Step accepted
# Iter:   70, time: 5.219e+00, f:  1.460e+04, |g|: 1.164e+01, |M^{-1}g|: 6.920e+02, Delta: 1.355e+01, inner iters:   220, |h|: 2.181e+02, |h|_M: 1.355e+01, df: -4.934e-01, rho: -6.052e-02. Step REJECTED!
# Iter:   71, time: 5.592e+00, f:  1.460e+04, |g|: 1.164e+01, |M^{-1}g|: 6.920e+02, Delta: 3.388e+00, inner iters:    99, |h|: 4.866e+01, |h|_M: 3.388e+00, df:  3.945e+00, rho:  1.083e+00. Step accepted
# Iter:   72, time: 5.748e+00, f:  1.459e+04, |g|: 6.992e+00, |M^{-1}g|: 2.427e+02, Delta: 8.470e+00, inner iters:   111, |h|: 1.323e+02, |h|_M: 8.470e+00, df:  2.325e+00, rho:  4.791e-01. Step accepted
# Iter:   73, time: 5.921e+00, f:  1.459e+04, |g|: 1.844e+01, |M^{-1}g|: 1.600e+03, Delta: 8.470e+00, inner iters:    45, |h|: 6.938e+00, |h|_M: 8.448e-01, df:  4.908e+00, rho:  1.003e+00. Step accepted
# Iter:   74, time: 5.993e+00, f:  1.459e+04, |g|: 4.688e+00, |M^{-1}g|: 1.305e+02, Delta: 8.470e+00, inner iters:   101, |h|: 1.293e+02, |h|_M: 8.470e+00, df: -1.310e+00, rho: -3.424e-01. Step REJECTED!
# Iter:   75, time: 6.149e+00, f:  1.459e+04, |g|: 4.688e+00, |M^{-1}g|: 1.305e+02, Delta: 2.118e+00, inner iters:    71, |h|: 2.846e+01, |h|_M: 2.118e+00, df:  1.211e+00, rho:  9.944e-01. Step accepted
# Iter:   76, time: 6.275e+00, f:  1.459e+04, |g|: 5.073e+00, |M^{-1}g|: 2.085e+02, Delta: 5.294e+00, inner iters:    95, |h|: 8.176e+01, |h|_M: 5.294e+00, df:  1.705e+00, rho:  6.457e-01. Step accepted
# Iter:   77, time: 6.452e+00, f:  1.458e+04, |g|: 1.090e+01, |M^{-1}g|: 5.097e+02, Delta: 5.294e+00, inner iters:   142, |h|: 8.263e+01, |h|_M: 5.294e+00, df:  4.516e+00, rho:  1.059e+00. Step accepted
# Iter:   78, time: 6.671e+00, f:  1.458e+04, |g|: 8.027e+00, |M^{-1}g|: 4.693e+02, Delta: 1.323e+01, inner iters:   232, |h|: 2.239e+02, |h|_M: 1.323e+01, df: -5.038e+00, rho: -9.175e-01. Step REJECTED!
# Iter:   79, time: 7.076e+00, f:  1.458e+04, |g|: 8.027e+00, |M^{-1}g|: 4.693e+02, Delta: 3.309e+00, inner iters:   116, |h|: 5.311e+01, |h|_M: 3.309e+00, df:  2.569e+00, rho:  1.071e+00. Step accepted
# Iter:   80, time: 7.272e+00, f:  1.458e+04, |g|: 5.116e+00, |M^{-1}g|: 3.697e+02, Delta: 8.272e+00, inner iters:   132, |h|: 1.415e+02, |h|_M: 8.272e+00, df:  5.741e-01, rho:  1.635e-01. Step accepted
# Iter:   81, time: 7.538e+00, f:  1.458e+04, |g|: 1.637e+01, |M^{-1}g|: 1.113e+03, Delta: 8.272e+00, inner iters:    78, |h|: 1.329e+01, |h|_M: 1.325e+00, df:  5.320e+00, rho:  1.009e+00. Step accepted
# Iter:   82, time: 7.671e+00, f:  1.457e+04, |g|: 3.695e+00, |M^{-1}g|: 7.591e+01, Delta: 8.272e+00, inner iters:    95, |h|: 1.441e+02, |h|_M: 8.272e+00, df: -1.535e+00, rho: -5.121e-01. Step REJECTED!
# Iter:   83, time: 7.828e+00, f:  1.457e+04, |g|: 3.695e+00, |M^{-1}g|: 7.591e+01, Delta: 2.068e+00, inner iters:    69, |h|: 3.463e+01, |h|_M: 2.068e+00, df:  8.637e-01, rho:  9.590e-01. Step accepted
# Iter:   84, time: 7.949e+00, f:  1.457e+04, |g|: 6.288e+00, |M^{-1}g|: 2.071e+02, Delta: 5.170e+00, inner iters:    99, |h|: 8.784e+01, |h|_M: 5.170e+00, df:  2.064e+00, rho:  9.169e-01. Step accepted
# Iter:   85, time: 8.115e+00, f:  1.457e+04, |g|: 9.042e+00, |M^{-1}g|: 4.059e+02, Delta: 1.292e+01, inner iters:   267, |h|: 2.020e+02, |h|_M: 1.292e+01, df: -1.824e+00, rho: -3.544e-01. Step REJECTED!
# Iter:   86, time: 8.594e+00, f:  1.457e+04, |g|: 9.042e+00, |M^{-1}g|: 4.059e+02, Delta: 3.231e+00, inner iters:   132, |h|: 4.894e+01, |h|_M: 3.231e+00, df:  2.637e+00, rho:  1.054e+00. Step accepted
# Iter:   87, time: 8.828e+00, f:  1.457e+04, |g|: 4.939e+00, |M^{-1}g|: 1.814e+02, Delta: 8.078e+00, inner iters:   139, |h|: 1.340e+02, |h|_M: 8.078e+00, df:  1.261e-01, rho:  4.337e-02. Step REJECTED!
# Iter:   88, time: 9.138e+00, f:  1.457e+04, |g|: 4.939e+00, |M^{-1}g|: 1.814e+02, Delta: 2.019e+00, inner iters:    85, |h|: 2.846e+01, |h|_M: 2.019e+00, df:  1.068e+00, rho:  1.012e+00. Step accepted
# Iter:   89, time: 9.294e+00, f:  1.456e+04, |g|: 4.016e+00, |M^{-1}g|: 1.240e+02, Delta: 5.049e+00, inner iters:   116, |h|: 8.246e+01, |h|_M: 5.049e+00, df:  1.424e+00, rho:  7.935e-01. Step accepted
# Iter:   90, time: 9.484e+00, f:  1.456e+04, |g|: 7.792e+00, |M^{-1}g|: 7.708e+02, Delta: 5.049e+00, inner iters:    98, |h|: 1.739e+01, |h|_M: 1.684e+00, df:  1.708e+00, rho:  1.019e+00. Step accepted
# Iter:   91, time: 9.632e+00, f:  1.456e+04, |g|: 2.539e+00, |M^{-1}g|: 6.195e+01, Delta: 5.049e+00, inner iters:    99, |h|: 7.979e+01, |h|_M: 5.049e+00, df:  5.337e-01, rho:  3.813e-01. Step accepted
# Iter:   92, time: 9.794e+00, f:  1.456e+04, |g|: 8.490e+00, |M^{-1}g|: 6.645e+02, Delta: 5.049e+00, inner iters:    86, |h|: 1.222e+01, |h|_M: 1.329e+00, df:  1.938e+00, rho:  1.007e+00. Step accepted
# Iter:   93, time: 9.932e+00, f:  1.456e+04, |g|: 2.259e+00, |M^{-1}g|: 4.629e+01, Delta: 5.049e+00, inner iters:    90, |h|: 7.766e+01, |h|_M: 5.049e+00, df: -3.354e-01, rho: -2.796e-01. Step REJECTED!
# Iter:   94, time: 1.008e+01, f:  1.456e+04, |g|: 2.259e+00, |M^{-1}g|: 4.629e+01, Delta: 1.262e+00, inner iters:    63, |h|: 1.830e+01, |h|_M: 1.262e+00, df:  3.383e-01, rho:  9.874e-01. Step accepted
# Iter:   95, time: 1.019e+01, f:  1.456e+04, |g|: 3.464e+00, |M^{-1}g|: 6.847e+01, Delta: 3.155e+00, inner iters:   104, |h|: 4.878e+01, |h|_M: 3.155e+00, df:  7.865e-01, rho:  8.486e-01. Step accepted
# Iter:   96, time: 1.036e+01, f:  1.456e+04, |g|: 5.738e+00, |M^{-1}g|: 2.500e+02, Delta: 3.155e+00, inner iters:   133, |h|: 5.136e+01, |h|_M: 3.155e+00, df:  1.400e+00, rho:  1.094e+00. Step accepted
# Iter:   97, time: 1.057e+01, f:  1.456e+04, |g|: 4.173e+00, |M^{-1}g|: 1.493e+02, Delta: 7.889e+00, inner iters:   215, |h|: 1.438e+02, |h|_M: 7.889e+00, df: -1.618e+00, rho: -9.104e-01. Step REJECTED!
# Iter:   98, time: 1.091e+01, f:  1.456e+04, |g|: 4.173e+00, |M^{-1}g|: 1.493e+02, Delta: 1.972e+00, inner iters:   126, |h|: 3.182e+01, |h|_M: 1.972e+00, df:  8.131e-01, rho:  1.069e+00. Step accepted
# Iter:   99, time: 1.111e+01, f:  1.456e+04, |g|: 3.163e+00, |M^{-1}g|: 8.324e+01, Delta: 4.930e+00, inner iters:   136, |h|: 8.749e+01, |h|_M: 4.930e+00, df:  3.115e-01, rho:  2.731e-01. Step accepted
# Iter:  100, time: 1.133e+01, f:  1.456e+04, |g|: 7.906e+00, |M^{-1}g|: 3.924e+02, Delta: 4.930e+00, inner iters:    58, |h|: 4.745e+00, |h|_M: 4.839e-01, df:  1.562e+00, rho:  1.005e+00. Step accepted
# Iter:  101, time: 1.143e+01, f:  1.455e+04, |g|: 1.828e+00, |M^{-1}g|: 4.664e+01, Delta: 4.930e+00, inner iters:   110, |h|: 8.711e+01, |h|_M: 4.930e+00, df: -1.138e+00, rho: -1.163e+00. Step REJECTED!
# Iter:  102, time: 1.161e+01, f:  1.455e+04, |g|: 1.828e+00, |M^{-1}g|: 4.664e+01, Delta: 1.233e+00, inner iters:    64, |h|: 1.971e+01, |h|_M: 1.233e+00, df:  2.855e-01, rho:  9.870e-01. Step accepted
# Iter:  103, time: 1.172e+01, f:  1.455e+04, |g|: 2.576e+00, |M^{-1}g|: 2.207e+02, Delta: 3.081e+00, inner iters:   121, |h|: 5.499e+01, |h|_M: 3.081e+00, df:  5.136e-01, rho:  7.216e-01. Step accepted
# Iter:  104, time: 1.192e+01, f:  1.455e+04, |g|: 4.713e+00, |M^{-1}g|: 2.011e+02, Delta: 3.081e+00, inner iters:   159, |h|: 6.225e+01, |h|_M: 3.081e+00, df:  1.192e+00, rho:  1.138e+00. Step accepted
# Iter:  105, time: 1.217e+01, f:  1.455e+04, |g|: 3.387e+00, |M^{-1}g|: 1.741e+02, Delta: 7.704e+00, inner iters:   298, |h|: 1.689e+02, |h|_M: 7.704e+00, df: -3.385e-01, rho: -2.711e-01. Step REJECTED!
# Iter:  106, time: 1.268e+01, f:  1.455e+04, |g|: 3.387e+00, |M^{-1}g|: 1.741e+02, Delta: 1.926e+00, inner iters:   133, |h|: 3.855e+01, |h|_M: 1.926e+00, df:  5.706e-01, rho:  1.073e+00. Step accepted
# Iter:  107, time: 1.291e+01, f:  1.455e+04, |g|: 2.542e+00, |M^{-1}g|: 8.333e+01, Delta: 4.815e+00, inner iters:   164, |h|: 1.048e+02, |h|_M: 4.815e+00, df:  4.923e-01, rho:  5.910e-01. Step accepted
# Iter:  108, time: 1.318e+01, f:  1.455e+04, |g|: 5.651e+00, |M^{-1}g|: 4.288e+02, Delta: 4.815e+00, inner iters:    68, |h|: 5.317e+00, |h|_M: 4.717e-01, df:  7.900e-01, rho:  1.012e+00. Step accepted
# Iter:  109, time: 1.329e+01, f:  1.455e+04, |g|: 1.303e+00, |M^{-1}g|: 2.704e+01, Delta: 4.815e+00, inner iters:   145, |h|: 1.147e+02, |h|_M: 4.815e+00, df: -2.568e-01, rho: -4.146e-01. Step REJECTED!
# Iter:  110, time: 1.353e+01, f:  1.455e+04, |g|: 1.303e+00, |M^{-1}g|: 2.704e+01, Delta: 1.204e+00, inner iters:    88, |h|: 2.585e+01, |h|_M: 1.204e+00, df:  1.879e-01, rho:  9.727e-01. Step accepted
# Iter:  111, time: 1.368e+01, f:  1.455e+04, |g|: 1.638e+00, |M^{-1}g|: 6.674e+01, Delta: 3.009e+00, inner iters:   148, |h|: 6.959e+01, |h|_M: 3.009e+00, df:  3.303e-01, rho:  7.621e-01. Step accepted
# Iter:  112, time: 1.399e+01, f:  1.455e+04, |g|: 3.694e+00, |M^{-1}g|: 2.121e+02, Delta: 3.009e+00, inner iters:   193, |h|: 7.085e+01, |h|_M: 3.009e+00, df:  6.696e-01, rho:  1.091e+00. Step accepted
# Iter:  113, time: 1.436e+01, f:  1.455e+04, |g|: 2.604e+00, |M^{-1}g|: 1.982e+02, Delta: 7.523e+00, inner iters:   449, |h|: 1.534e+02, |h|_M: 7.523e+00, df: -1.243e-01, rho: -1.607e-01. Step REJECTED!
# Iter:  114, time: 1.509e+01, f:  1.455e+04, |g|: 2.604e+00, |M^{-1}g|: 1.982e+02, Delta: 1.881e+00, inner iters:   167, |h|: 4.399e+01, |h|_M: 1.881e+00, df:  3.764e-01, rho:  1.071e+00. Step accepted
# Iter:  115, time: 1.535e+01, f:  1.455e+04, |g|: 1.844e+00, |M^{-1}g|: 9.809e+01, Delta: 4.702e+00, inner iters:   192, |h|: 1.166e+02, |h|_M: 4.702e+00, df: -1.043e-01, rho: -2.008e-01. Step REJECTED!
# Iter:  116, time: 1.565e+01, f:  1.455e+04, |g|: 1.844e+00, |M^{-1}g|: 9.809e+01, Delta: 1.175e+00, inner iters:   126, |h|: 2.482e+01, |h|_M: 1.175e+00, df:  2.021e-01, rho:  1.008e+00. Step accepted
# Iter:  117, time: 1.584e+01, f:  1.455e+04, |g|: 1.468e+00, |M^{-1}g|: 3.963e+01, Delta: 2.939e+00, inner iters:   146, |h|: 7.373e+01, |h|_M: 2.939e+00, df:  1.929e-01, rho:  5.999e-01. Step accepted
# Iter:  118, time: 1.608e+01, f:  1.455e+04, |g|: 4.136e+00, |M^{-1}g|: 2.805e+02, Delta: 2.939e+00, inner iters:   214, |h|: 7.099e+01, |h|_M: 2.939e+00, df:  6.277e-01, rho:  1.074e+00. Step accepted
# Iter:  119, time: 1.643e+01, f:  1.455e+04, |g|: 3.227e+00, |M^{-1}g|: 2.303e+02, Delta: 7.347e+00, inner iters:   421, |h|: 1.559e+02, |h|_M: 7.347e+00, df: -1.488e+00, rho: -1.984e+00. Step REJECTED!
# Iter:  120, time: 1.712e+01, f:  1.455e+04, |g|: 3.227e+00, |M^{-1}g|: 2.303e+02, Delta: 1.837e+00, inner iters:   170, |h|: 4.784e+01, |h|_M: 1.837e+00, df:  3.545e-01, rho:  1.024e+00. Step accepted
# Iter:  121, time: 1.740e+01, f:  1.455e+04, |g|: 2.507e+00, |M^{-1}g|: 1.611e+02, Delta: 4.592e+00, inner iters:   197, |h|: 1.210e+02, |h|_M: 4.592e+00, df: -2.404e-01, rho: -4.360e-01. Step REJECTED!
# Iter:  122, time: 1.773e+01, f:  1.455e+04, |g|: 2.507e+00, |M^{-1}g|: 1.611e+02, Delta: 1.148e+00, inner iters:   111, |h|: 2.363e+01, |h|_M: 1.148e+00, df:  2.217e-01, rho:  1.000e+00. Step accepted
# Iter:  123, time: 1.791e+01, f:  1.455e+04, |g|: 1.718e+00, |M^{-1}g|: 4.778e+01, Delta: 2.870e+00, inner iters:   142, |h|: 7.890e+01, |h|_M: 2.870e+00, df:  1.053e-01, rho:  3.086e-01. Step accepted
# Iter:  124, time: 1.815e+01, f:  1.455e+04, |g|: 4.671e+00, |M^{-1}g|: 3.923e+02, Delta: 2.870e+00, inner iters:   120, |h|: 1.865e+01, |h|_M: 1.148e+00, df:  5.177e-01, rho:  9.631e-01. Step accepted
# Iter:  125, time: 1.834e+01, f:  1.455e+04, |g|: 1.667e+00, |M^{-1}g|: 5.044e+01, Delta: 2.870e+00, inner iters:   128, |h|: 8.261e+01, |h|_M: 2.870e+00, df:  7.115e-02, rho:  2.132e-01. Step accepted
# Iter:  126, time: 1.856e+01, f:  1.455e+04, |g|: 4.800e+00, |M^{-1}g|: 4.157e+02, Delta: 2.870e+00, inner iters:   106, |h|: 1.441e+01, |h|_M: 9.347e-01, df:  5.374e-01, rho:  9.923e-01. Step accepted
# Iter:  127, time: 1.874e+01, f:  1.455e+04, |g|: 1.190e+00, |M^{-1}g|: 2.996e+01, Delta: 2.870e+00, inner iters:   117, |h|: 8.700e+01, |h|_M: 2.870e+00, df:  6.585e-02, rho:  2.105e-01. Step accepted
# Iter:  128, time: 1.893e+01, f:  1.455e+04, |g|: 4.155e+00, |M^{-1}g|: 4.393e+02, Delta: 2.870e+00, inner iters:    97, |h|: 1.158e+01, |h|_M: 7.243e-01, df:  5.300e-01, rho:  1.004e+00. Step accepted
# Iter:  129, time: 1.910e+01, f:  1.455e+04, |g|: 9.927e-01, |M^{-1}g|: 2.409e+01, Delta: 2.870e+00, inner iters:   104, |h|: 8.906e+01, |h|_M: 2.870e+00, df:  6.560e-02, rho:  2.164e-01. Step accepted
# Iter:  130, time: 1.927e+01, f:  1.455e+04, |g|: 4.134e+00, |M^{-1}g|: 4.180e+02, Delta: 2.870e+00, inner iters:    92, |h|: 8.858e+00, |h|_M: 6.364e-01, df:  5.183e-01, rho:  1.006e+00. Step accepted
# Iter:  131, time: 1.943e+01, f:  1.454e+04, |g|: 7.961e-01, |M^{-1}g|: 1.870e+01, Delta: 2.870e+00, inner iters:    98, |h|: 8.911e+01, |h|_M: 2.870e+00, df:  1.245e-01, rho:  4.116e-01. Step accepted
# Iter:  132, time: 1.959e+01, f:  1.454e+04, |g|: 4.240e+00, |M^{-1}g|: 4.461e+02, Delta: 2.870e+00, inner iters:    68, |h|: 5.607e+00, |h|_M: 4.420e-01, df:  4.213e-01, rho:  1.009e+00. Step accepted
# Iter:  133, time: 1.970e+01, f:  1.454e+04, |g|: 1.053e+00, |M^{-1}g|: 2.282e+01, Delta: 2.870e+00, inner iters:   106, |h|: 8.740e+01, |h|_M: 2.870e+00, df:  8.440e-02, rho:  2.759e-01. Step accepted
# Iter:  134, time: 1.987e+01, f:  1.454e+04, |g|: 3.466e+00, |M^{-1}g|: 4.351e+02, Delta: 2.870e+00, inner iters:    83, |h|: 1.036e+01, |h|_M: 7.191e-01, df:  4.546e-01, rho:  1.014e+00. Step accepted
# Iter:  135, time: 2.001e+01, f:  1.454e+04, |g|: 9.736e-01, |M^{-1}g|: 2.091e+01, Delta: 2.870e+00, inner iters:   118, |h|: 8.678e+01, |h|_M: 2.870e+00, df:  1.253e-01, rho:  4.242e-01. Step accepted
# Iter:  136, time: 2.020e+01, f:  1.454e+04, |g|: 3.524e+00, |M^{-1}g|: 3.732e+02, Delta: 2.870e+00, inner iters:    99, |h|: 1.088e+01, |h|_M: 6.830e-01, df:  3.984e-01, rho:  1.012e+00. Step accepted
# Iter:  137, time: 2.037e+01, f:  1.454e+04, |g|: 9.842e-01, |M^{-1}g|: 2.121e+01, Delta: 2.870e+00, inner iters:   118, |h|: 8.893e+01, |h|_M: 2.870e+00, df:  9.708e-02, rho:  3.617e-01. Step accepted
# Iter:  138, time: 2.056e+01, f:  1.454e+04, |g|: 3.696e+00, |M^{-1}g|: 3.841e+02, Delta: 2.870e+00, inner iters:   106, |h|: 9.811e+00, |h|_M: 6.209e-01, df:  3.825e-01, rho:  1.009e+00. Step accepted
# Iter:  139, time: 2.073e+01, f:  1.454e+04, |g|: 8.626e-01, |M^{-1}g|: 1.970e+01, Delta: 2.870e+00, inner iters:   125, |h|: 8.724e+01, |h|_M: 2.870e+00, df:  8.302e-02, rho:  3.469e-01. Step accepted
# Iter:  140, time: 2.095e+01, f:  1.454e+04, |g|: 3.795e+00, |M^{-1}g|: 3.344e+02, Delta: 2.870e+00, inner iters:   109, |h|: 1.005e+01, |h|_M: 6.108e-01, df:  3.441e-01, rho:  1.007e+00. Step accepted
# Iter:  141, time: 2.113e+01, f:  1.454e+04, |g|: 8.168e-01, |M^{-1}g|: 1.641e+01, Delta: 2.870e+00, inner iters:   132, |h|: 8.763e+01, |h|_M: 2.870e+00, df:  8.193e-02, rho:  3.821e-01. Step accepted
# Iter:  142, time: 2.135e+01, f:  1.454e+04, |g|: 3.327e+00, |M^{-1}g|: 3.092e+02, Delta: 2.870e+00, inner iters:   105, |h|: 7.558e+00, |h|_M: 5.146e-01, df:  2.853e-01, rho:  1.005e+00. Step accepted
# Iter:  143, time: 2.152e+01, f:  1.454e+04, |g|: 8.304e-01, |M^{-1}g|: 1.371e+01, Delta: 2.870e+00, inner iters:   147, |h|: 8.457e+01, |h|_M: 2.870e+00, df:  5.724e-02, rho:  3.005e-01. Step accepted
# Iter:  144, time: 2.176e+01, f:  1.454e+04, |g|: 2.946e+00, |M^{-1}g|: 3.069e+02, Delta: 2.870e+00, inner iters:   124, |h|: 1.207e+01, |h|_M: 7.449e-01, df:  2.738e-01, rho:  1.011e+00. Step accepted
# Iter:  145, time: 2.196e+01, f:  1.454e+04, |g|: 7.265e-01, |M^{-1}g|: 1.814e+01, Delta: 2.870e+00, inner iters:   141, |h|: 8.606e+01, |h|_M: 2.870e+00, df:  4.463e-02, rho:  2.787e-01. Step accepted
# Iter:  146, time: 2.220e+01, f:  1.454e+04, |g|: 3.172e+00, |M^{-1}g|: 2.879e+02, Delta: 2.870e+00, inner iters:    48, |h|: 2.395e+00, |h|_M: 1.885e-01, df:  1.861e-01, rho:  1.001e+00. Step accepted
# Iter:  147, time: 2.228e+01, f:  1.454e+04, |g|: 8.631e-01, |M^{-1}g|: 2.423e+01, Delta: 2.870e+00, inner iters:   224, |h|: 8.413e+01, |h|_M: 2.870e+00, df:  2.131e-02, rho:  1.187e-01. Step accepted
# Iter:  148, time: 2.266e+01, f:  1.454e+04, |g|: 2.645e+00, |M^{-1}g|: 3.355e+02, Delta: 2.870e+00, inner iters:    61, |h|: 3.381e+00, |h|_M: 2.045e-01, df:  2.061e-01, rho:  1.001e+00. Step accepted
# Iter:  149, time: 2.276e+01, f:  1.454e+04, |g|: 7.282e-01, |M^{-1}g|: 1.453e+01, Delta: 2.870e+00, inner iters:   228, |h|: 8.603e+01, |h|_M: 2.870e+00, df:  1.209e-02, rho:  7.629e-02. Step accepted
#
# Optimization finished!
# Algorithm terminated due to insufficient relative decrease: 8.313e-07 < 1.000e-06
# Final objective value: 1.454e+04
# Norm of Riemannian gradient: 7.282e-01
# Norm of preconditioned Riemannian gradient: 1.453e+01
# Total elapsed computation time: 2.314e+01 seconds
#
#
# Found first-order critical point with value F(Y) = 14541!  Elapsed computation time: 23.141 seconds
#
# Checking second order optimality ...
# Saddle point detected! Curvature along escape direction: -0.400874.  Elapsed computation time: 0.026 seconds (5 LOBPCG iterations).
#
#
# ====== RIEMANNIAN STAIRCASE (level r = 4) ======
#
# Truncated-Newton trust-region optimization:
#
# Iter:    0, time: 0.000e+00, f:  1.454e+04, |g|: 8.166e+00, |M^{-1}g|: 5.990e+02, Delta: 1.000e+00, inner iters:     0, |h|: 2.680e+01, |h|_M: 1.000e+00, df:  2.409e+03, rho:  3.853e-01. Step accepted
# Iter:    1, time: 4.000e-03, f:  1.213e+04, |g|: 3.819e+02, |M^{-1}g|: 2.099e+05, Delta: 1.000e+00, inner iters:     0, |h|: 3.047e+01, |h|_M: 1.000e+00, df:  2.725e+03, rho:  4.865e-01. Step accepted
# Iter:    2, time: 1.000e-02, f:  9.407e+03, |g|: 7.417e+02, |M^{-1}g|: 3.953e+05, Delta: 1.000e+00, inner iters:     1, |h|: 3.489e+01, |h|_M: 1.000e+00, df:  4.779e+03, rho:  5.604e-01. Step accepted
# Iter:    3, time: 1.600e-02, f:  4.628e+03, |g|: 7.289e+02, |M^{-1}g|: 3.858e+05, Delta: 1.000e+00, inner iters:     2, |h|: 2.804e+01, |h|_M: 1.000e+00, df:  3.019e+03, rho:  7.058e-01. Step accepted
# Iter:    4, time: 2.600e-02, f:  1.609e+03, |g|: 4.666e+02, |M^{-1}g|: 1.395e+05, Delta: 1.000e+00, inner iters:     2, |h|: 5.923e+00, |h|_M: 2.116e-01, df:  5.032e+02, rho:  9.976e-01. Step accepted
# Iter:    5, time: 3.400e-02, f:  1.106e+03, |g|: 3.169e+02, |M^{-1}g|: 1.155e+04, Delta: 1.000e+00, inner iters:     7, |h|: 1.377e+01, |h|_M: 1.000e+00, df:  1.041e+02, rho:  9.505e-01. Step accepted
# Iter:    6, time: 5.200e-02, f:  1.002e+03, |g|: 3.084e+02, |M^{-1}g|: 8.392e+03, Delta: 2.500e+00, inner iters:    10, |h|: 2.206e+01, |h|_M: 2.500e+00, df:  1.353e+02, rho:  7.839e-01. Step accepted
# Iter:    7, time: 7.500e-02, f:  8.667e+02, |g|: 3.025e+02, |M^{-1}g|: 7.194e+03, Delta: 2.500e+00, inner iters:    13, |h|: 3.188e+01, |h|_M: 2.500e+00, df:  1.567e+02, rho:  8.867e-01. Step accepted
# Iter:    8, time: 1.050e-01, f:  7.100e+02, |g|: 2.808e+02, |M^{-1}g|: 9.102e+03, Delta: 2.500e+00, inner iters:    14, |h|: 2.619e+01, |h|_M: 2.500e+00, df:  1.320e+02, rho:  8.679e-01. Step accepted
# Iter:    9, time: 1.360e-01, f:  5.780e+02, |g|: 2.569e+02, |M^{-1}g|: 6.462e+03, Delta: 2.500e+00, inner iters:    15, |h|: 3.081e+01, |h|_M: 2.500e+00, df:  1.027e+02, rho:  9.131e-01. Step accepted
# Iter:   10, time: 1.670e-01, f:  4.753e+02, |g|: 2.252e+02, |M^{-1}g|: 4.728e+03, Delta: 6.250e+00, inner iters:    20, |h|: 5.163e+01, |h|_M: 6.250e+00, df:  1.272e+02, rho:  7.783e-01. Step accepted
# Iter:   11, time: 2.060e-01, f:  3.481e+02, |g|: 1.607e+02, |M^{-1}g|: 7.453e+03, Delta: 6.250e+00, inner iters:    25, |h|: 4.812e+01, |h|_M: 6.250e+00, df:  1.014e+02, rho:  6.618e-01. Step accepted
# Iter:   12, time: 2.550e-01, f:  2.467e+02, |g|: 1.010e+02, |M^{-1}g|: 5.068e+03, Delta: 6.250e+00, inner iters:    27, |h|: 7.878e+01, |h|_M: 6.250e+00, df: -8.728e+02, rho: -6.294e+00. Step REJECTED!
# Iter:   13, time: 3.060e-01, f:  2.467e+02, |g|: 1.010e+02, |M^{-1}g|: 5.068e+03, Delta: 1.562e+00, inner iters:    20, |h|: 1.868e+01, |h|_M: 1.562e+00, df:  5.919e+01, rho:  9.761e-01. Step accepted
# Iter:   14, time: 3.450e-01, f:  1.875e+02, |g|: 7.526e+01, |M^{-1}g|: 1.592e+03, Delta: 3.906e+00, inner iters:    24, |h|: 3.840e+01, |h|_M: 3.906e+00, df:  2.998e+01, rho:  9.379e-01. Step accepted
# Iter:   15, time: 3.920e-01, f:  1.575e+02, |g|: 4.054e+01, |M^{-1}g|: 1.128e+03, Delta: 9.766e+00, inner iters:    62, |h|: 1.618e+02, |h|_M: 9.766e+00, df: -2.671e+03, rho: -6.517e+01. Step REJECTED!
# Iter:   16, time: 4.940e-01, f:  1.575e+02, |g|: 4.054e+01, |M^{-1}g|: 1.128e+03, Delta: 2.441e+00, inner iters:    40, |h|: 3.202e+01, |h|_M: 2.441e+00, df:  1.842e+01, rho:  9.962e-01. Step accepted
# Iter:   17, time: 5.670e-01, f:  1.391e+02, |g|: 1.637e+01, |M^{-1}g|: 7.937e+02, Delta: 6.104e+00, inner iters:    43, |h|: 1.475e+02, |h|_M: 6.104e+00, df: -2.428e+02, rho: -1.608e+01. Step REJECTED!
# Iter:   18, time: 6.370e-01, f:  1.391e+02, |g|: 1.637e+01, |M^{-1}g|: 7.937e+02, Delta: 1.526e+00, inner iters:    36, |h|: 3.245e+01, |h|_M: 1.526e+00, df:  4.189e+00, rho:  7.731e-01. Step accepted
# Iter:   19, time: 6.960e-01, f:  1.349e+02, |g|: 1.082e+01, |M^{-1}g|: 7.577e+02, Delta: 1.526e+00, inner iters:    38, |h|: 3.618e+01, |h|_M: 1.526e+00, df:  4.643e+00, rho:  8.742e-01. Step accepted
# Iter:   20, time: 7.590e-01, f:  1.303e+02, |g|: 8.750e+00, |M^{-1}g|: 5.776e+02, Delta: 1.526e+00, inner iters:    38, |h|: 3.740e+01, |h|_M: 1.526e+00, df:  3.856e+00, rho:  8.134e-01. Step accepted
# Iter:   21, time: 8.250e-01, f:  1.264e+02, |g|: 9.202e+00, |M^{-1}g|: 8.932e+02, Delta: 1.526e+00, inner iters:    36, |h|: 3.949e+01, |h|_M: 1.526e+00, df:  4.636e+00, rho:  9.508e-01. Step accepted
# Iter:   22, time: 9.000e-01, f:  1.218e+02, |g|: 1.045e+01, |M^{-1}g|: 8.028e+02, Delta: 3.815e+00, inner iters:    40, |h|: 1.070e+02, |h|_M: 3.815e+00, df: -2.383e+01, rho: -2.211e+00. Step REJECTED!
# Iter:   23, time: 9.850e-01, f:  1.218e+02, |g|: 1.045e+01, |M^{-1}g|: 8.028e+02, Delta: 9.537e-01, inner iters:    26, |h|: 1.947e+01, |h|_M: 9.537e-01, df:  4.531e+00, rho:  1.065e+00. Step accepted
# Iter:   24, time: 1.031e+00, f:  1.172e+02, |g|: 7.487e+00, |M^{-1}g|: 8.576e+02, Delta: 2.384e+00, inner iters:    26, |h|: 6.142e+01, |h|_M: 2.384e+00, df: -9.200e-01, rho: -1.156e-01. Step REJECTED!
# Iter:   25, time: 1.075e+00, f:  1.172e+02, |g|: 7.487e+00, |M^{-1}g|: 8.576e+02, Delta: 5.960e-01, inner iters:    18, |h|: 1.427e+01, |h|_M: 5.960e-01, df:  2.572e+00, rho:  1.047e+00. Step accepted
# Iter:   26, time: 1.109e+00, f:  1.147e+02, |g|: 8.302e+00, |M^{-1}g|: 5.497e+02, Delta: 1.490e+00, inner iters:    21, |h|: 3.790e+01, |h|_M: 1.490e+00, df:  4.098e+00, rho:  6.833e-01. Step accepted
# Iter:   27, time: 1.149e+00, f:  1.106e+02, |g|: 1.879e+01, |M^{-1}g|: 1.227e+03, Delta: 1.490e+00, inner iters:    27, |h|: 3.738e+01, |h|_M: 1.490e+00, df:  1.073e+01, rho:  1.015e+00. Step accepted
# Iter:   28, time: 1.202e+00, f:  9.984e+01, |g|: 1.632e+01, |M^{-1}g|: 1.133e+03, Delta: 3.725e+00, inner iters:    49, |h|: 1.039e+02, |h|_M: 3.725e+00, df: -2.474e+00, rho: -1.484e-01. Step REJECTED!
# Iter:   29, time: 1.291e+00, f:  9.984e+01, |g|: 1.632e+01, |M^{-1}g|: 1.133e+03, Delta: 9.313e-01, inner iters:    22, |h|: 2.004e+01, |h|_M: 9.313e-01, df:  7.934e+00, rho:  1.094e+00. Step accepted
# Iter:   30, time: 1.332e+00, f:  9.190e+01, |g|: 1.034e+01, |M^{-1}g|: 1.751e+03, Delta: 2.328e+00, inner iters:    24, |h|: 5.775e+01, |h|_M: 2.328e+00, df: -5.038e-01, rho: -4.542e-02. Step REJECTED!
# Iter:   31, time: 1.375e+00, f:  9.190e+01, |g|: 1.034e+01, |M^{-1}g|: 1.751e+03, Delta: 5.821e-01, inner iters:    17, |h|: 1.343e+01, |h|_M: 5.821e-01, df:  3.773e+00, rho:  1.018e+00. Step accepted
# Iter:   32, time: 1.409e+00, f:  8.813e+01, |g|: 1.081e+01, |M^{-1}g|: 1.355e+03, Delta: 1.455e+00, inner iters:    21, |h|: 3.319e+01, |h|_M: 1.455e+00, df:  6.957e+00, rho:  9.608e-01. Step accepted
# Iter:   33, time: 1.447e+00, f:  8.117e+01, |g|: 1.626e+01, |M^{-1}g|: 1.327e+03, Delta: 3.638e+00, inner iters:    31, |h|: 9.152e+01, |h|_M: 3.638e+00, df: -2.158e+01, rho: -1.205e+00. Step REJECTED!
# Iter:   34, time: 1.499e+00, f:  8.117e+01, |g|: 1.626e+01, |M^{-1}g|: 1.327e+03, Delta: 9.095e-01, inner iters:    23, |h|: 2.171e+01, |h|_M: 9.095e-01, df:  7.541e+00, rho:  9.941e-01. Step accepted
# Iter:   35, time: 1.543e+00, f:  7.363e+01, |g|: 1.224e+01, |M^{-1}g|: 9.112e+02, Delta: 2.274e+00, inner iters:    26, |h|: 5.647e+01, |h|_M: 2.274e+00, df:  4.450e+00, rho:  4.329e-01. Step accepted
# Iter:   36, time: 1.590e+00, f:  6.918e+01, |g|: 3.179e+01, |M^{-1}g|: 4.559e+03, Delta: 2.274e+00, inner iters:    17, |h|: 5.761e+00, |h|_M: 4.091e-01, df:  1.051e+01, rho:  1.008e+00. Step accepted
# Iter:   37, time: 1.621e+00, f:  5.867e+01, |g|: 7.022e+00, |M^{-1}g|: 3.602e+02, Delta: 2.274e+00, inner iters:    23, |h|: 6.406e+01, |h|_M: 2.274e+00, df:  1.113e+00, rho:  1.694e-01. Step accepted
# Iter:   38, time: 1.664e+00, f:  5.756e+01, |g|: 2.512e+01, |M^{-1}g|: 4.075e+03, Delta: 2.274e+00, inner iters:    21, |h|: 8.825e+00, |h|_M: 4.154e-01, df:  8.764e+00, rho:  1.005e+00. Step accepted
# Iter:   39, time: 1.702e+00, f:  4.879e+01, |g|: 4.496e+00, |M^{-1}g|: 2.073e+02, Delta: 2.274e+00, inner iters:    25, |h|: 7.563e+01, |h|_M: 2.274e+00, df: -1.333e+00, rho: -3.207e-01. Step REJECTED!
# Iter:   40, time: 1.768e+00, f:  4.879e+01, |g|: 4.496e+00, |M^{-1}g|: 2.073e+02, Delta: 5.684e-01, inner iters:    18, |h|: 1.855e+01, |h|_M: 5.684e-01, df:  1.145e+00, rho:  9.197e-01. Step accepted
# Iter:   41, time: 1.803e+00, f:  4.765e+01, |g|: 7.755e+00, |M^{-1}g|: 6.229e+02, Delta: 1.421e+00, inner iters:    30, |h|: 4.832e+01, |h|_M: 1.421e+00, df:  2.613e+00, rho:  8.969e-01. Step accepted
# Iter:   42, time: 1.856e+00, f:  4.504e+01, |g|: 1.125e+01, |M^{-1}g|: 1.684e+03, Delta: 1.421e+00, inner iters:    27, |h|: 8.393e+00, |h|_M: 3.591e-01, df:  2.055e+00, rho:  1.021e+00. Step accepted
# Iter:   43, time: 1.903e+00, f:  4.298e+01, |g|: 3.000e+00, |M^{-1}g|: 1.509e+02, Delta: 1.421e+00, inner iters:    27, |h|: 5.078e+01, |h|_M: 1.421e+00, df:  4.775e-01, rho:  2.677e-01. Step accepted
# Iter:   44, time: 1.952e+00, f:  4.250e+01, |g|: 1.213e+01, |M^{-1}g|: 1.894e+03, Delta: 1.421e+00, inner iters:    24, |h|: 5.701e+00, |h|_M: 2.647e-01, df:  2.297e+00, rho:  1.007e+00. Step accepted
# Iter:   45, time: 1.996e+00, f:  4.021e+01, |g|: 1.832e+00, |M^{-1}g|: 1.257e+02, Delta: 1.421e+00, inner iters:    26, |h|: 5.261e+01, |h|_M: 1.421e+00, df: -4.449e-01, rho: -3.703e-01. Step REJECTED!
# Iter:   46, time: 2.041e+00, f:  4.021e+01, |g|: 1.832e+00, |M^{-1}g|: 1.257e+02, Delta: 3.553e-01, inner iters:    20, |h|: 1.294e+01, |h|_M: 3.553e-01, df:  3.396e-01, rho:  9.523e-01. Step accepted
# Iter:   47, time: 2.078e+00, f:  3.987e+01, |g|: 3.507e+00, |M^{-1}g|: 2.189e+02, Delta: 8.882e-01, inner iters:    32, |h|: 3.311e+01, |h|_M: 8.882e-01, df:  7.160e-01, rho:  8.150e-01. Step accepted
# Iter:   48, time: 2.133e+00, f:  3.915e+01, |g|: 6.521e+00, |M^{-1}g|: 7.998e+02, Delta: 8.882e-01, inner iters:    45, |h|: 3.367e+01, |h|_M: 8.882e-01, df:  1.212e+00, rho:  1.080e+00. Step accepted
# Iter:   49, time: 2.214e+00, f:  3.794e+01, |g|: 5.285e+00, |M^{-1}g|: 6.597e+02, Delta: 2.220e+00, inner iters:    49, |h|: 8.775e+01, |h|_M: 2.220e+00, df: -6.136e+01, rho: -4.592e+01. Step REJECTED!
# Iter:   50, time: 2.296e+00, f:  3.794e+01, |g|: 5.285e+00, |M^{-1}g|: 6.597e+02, Delta: 5.551e-01, inner iters:    37, |h|: 2.064e+01, |h|_M: 5.551e-01, df:  3.532e-01, rho:  6.524e-01. Step accepted
# Iter:   51, time: 2.359e+00, f:  3.759e+01, |g|: 5.927e+00, |M^{-1}g|: 9.928e+02, Delta: 5.551e-01, inner iters:    14, |h|: 1.114e+00, |h|_M: 5.786e-02, df:  3.141e-01, rho:  1.002e+00. Step accepted
# Iter:   52, time: 2.385e+00, f:  3.727e+01, |g|: 2.852e+00, |M^{-1}g|: 9.482e+01, Delta: 5.551e-01, inner iters:    31, |h|: 2.180e+01, |h|_M: 5.551e-01, df:  8.320e-02, rho:  2.554e-01. Step accepted
# Iter:   53, time: 2.441e+00, f:  3.719e+01, |g|: 6.297e+00, |M^{-1}g|: 1.142e+03, Delta: 5.551e-01, inner iters:    14, |h|: 1.255e+00, |h|_M: 6.079e-02, df:  3.332e-01, rho:  1.002e+00. Step accepted
# Iter:   54, time: 2.468e+00, f:  3.686e+01, |g|: 3.168e+00, |M^{-1}g|: 9.079e+01, Delta: 5.551e-01, inner iters:    35, |h|: 2.214e+01, |h|_M: 5.551e-01, df:  2.498e-01, rho:  8.019e-01. Step accepted
# Iter:   55, time: 2.531e+00, f:  3.661e+01, |g|: 4.437e+00, |M^{-1}g|: 3.812e+02, Delta: 5.551e-01, inner iters:    46, |h|: 2.184e+01, |h|_M: 5.551e-01, df:  4.490e-01, rho:  1.076e+00. Step accepted
# Iter:   56, time: 2.613e+00, f:  3.616e+01, |g|: 3.287e+00, |M^{-1}g|: 4.369e+02, Delta: 1.388e+00, inner iters:    48, |h|: 5.458e+01, |h|_M: 1.388e+00, df: -3.040e+00, rho: -4.679e+00. Step REJECTED!
# Iter:   57, time: 2.697e+00, f:  3.616e+01, |g|: 3.287e+00, |M^{-1}g|: 4.369e+02, Delta: 3.469e-01, inner iters:    35, |h|: 1.196e+01, |h|_M: 3.469e-01, df:  2.541e-01, rho:  1.016e+00. Step accepted
# Iter:   58, time: 2.760e+00, f:  3.590e+01, |g|: 2.888e+00, |M^{-1}g|: 1.326e+02, Delta: 8.674e-01, inner iters:    39, |h|: 3.284e+01, |h|_M: 8.674e-01, df: -2.466e-01, rho: -5.986e-01. Step REJECTED!
# Iter:   59, time: 2.828e+00, f:  3.590e+01, |g|: 2.888e+00, |M^{-1}g|: 1.326e+02, Delta: 2.168e-01, inner iters:    26, |h|: 6.252e+00, |h|_M: 2.168e-01, df:  1.487e-01, rho:  1.006e+00. Step accepted
# Iter:   60, time: 2.876e+00, f:  3.575e+01, |g|: 1.887e+00, |M^{-1}g|: 8.060e+01, Delta: 5.421e-01, inner iters:    32, |h|: 1.940e+01, |h|_M: 5.421e-01, df:  2.169e-01, rho:  8.794e-01. Step accepted
# Iter:   61, time: 2.933e+00, f:  3.554e+01, |g|: 4.763e+00, |M^{-1}g|: 3.531e+02, Delta: 5.421e-01, inner iters:    42, |h|: 1.786e+01, |h|_M: 5.421e-01, df:  3.963e-01, rho:  9.961e-01. Step accepted
# Iter:   62, time: 3.007e+00, f:  3.514e+01, |g|: 3.298e+00, |M^{-1}g|: 2.024e+02, Delta: 1.355e+00, inner iters:    61, |h|: 4.977e+01, |h|_M: 1.355e+00, df: -8.778e-01, rho: -1.341e+00. Step REJECTED!
# Iter:   63, time: 3.112e+00, f:  3.514e+01, |g|: 3.298e+00, |M^{-1}g|: 2.024e+02, Delta: 3.388e-01, inner iters:    35, |h|: 1.041e+01, |h|_M: 3.388e-01, df:  3.015e-01, rho:  1.064e+00. Step accepted
# Iter:   64, time: 3.175e+00, f:  3.484e+01, |g|: 2.875e+00, |M^{-1}g|: 1.885e+02, Delta: 8.470e-01, inner iters:    41, |h|: 2.871e+01, |h|_M: 8.470e-01, df:  2.146e-01, rho:  5.368e-01. Step accepted
# Iter:   65, time: 3.249e+00, f:  3.462e+01, |g|: 5.716e+00, |M^{-1}g|: 6.550e+02, Delta: 8.470e-01, inner iters:    33, |h|: 4.423e+00, |h|_M: 2.170e-01, df:  4.716e-01, rho:  1.020e+00. Step accepted
# Iter:   66, time: 3.310e+00, f:  3.415e+01, |g|: 1.105e+00, |M^{-1}g|: 4.912e+01, Delta: 8.470e-01, inner iters:    33, |h|: 3.072e+01, |h|_M: 8.470e-01, df: -2.549e-01, rho: -7.952e-01. Step REJECTED!
# Iter:   67, time: 3.370e+00, f:  3.415e+01, |g|: 1.105e+00, |M^{-1}g|: 4.912e+01, Delta: 2.118e-01, inner iters:    23, |h|: 7.298e+00, |h|_M: 2.118e-01, df:  9.061e-02, rho:  9.963e-01. Step accepted
# Iter:   68, time: 3.413e+00, f:  3.406e+01, |g|: 2.127e+00, |M^{-1}g|: 1.422e+02, Delta: 5.294e-01, inner iters:    35, |h|: 1.937e+01, |h|_M: 5.294e-01, df:  2.236e-01, rho:  9.332e-01. Step accepted
# Iter:   69, time: 3.476e+00, f:  3.384e+01, |g|: 3.544e+00, |M^{-1}g|: 3.689e+02, Delta: 1.323e+00, inner iters:    59, |h|: 5.372e+01, |h|_M: 1.323e+00, df: -1.200e-01, rho: -2.332e-01. Step REJECTED!
# Iter:   70, time: 3.577e+00, f:  3.384e+01, |g|: 3.544e+00, |M^{-1}g|: 3.689e+02, Delta: 3.309e-01, inner iters:    42, |h|: 1.187e+01, |h|_M: 3.309e-01, df:  2.520e-01, rho:  1.042e+00. Step accepted
# Iter:   71, time: 3.657e+00, f:  3.359e+01, |g|: 2.385e+00, |M^{-1}g|: 8.120e+01, Delta: 8.272e-01, inner iters:    45, |h|: 3.414e+01, |h|_M: 8.272e-01, df:  8.493e-02, rho:  2.823e-01. Step accepted
# Iter:   72, time: 3.737e+00, f:  3.350e+01, |g|: 5.931e+00, |M^{-1}g|: 1.313e+03, Delta: 8.272e-01, inner iters:    10, |h|: 8.504e-01, |h|_M: 2.791e-02, df:  2.700e-01, rho:  1.003e+00. Step accepted
# Iter:   73, time: 3.758e+00, f:  3.323e+01, |g|: 3.055e+00, |M^{-1}g|: 1.192e+02, Delta: 8.272e-01, inner iters:    48, |h|: 3.639e+01, |h|_M: 8.272e-01, df:  6.408e-03, rho:  2.009e-02. Step REJECTED!
# Iter:   74, time: 3.841e+00, f:  3.323e+01, |g|: 3.055e+00, |M^{-1}g|: 1.192e+02, Delta: 2.068e-01, inner iters:    35, |h|: 6.820e+00, |h|_M: 2.068e-01, df:  1.504e-01, rho:  9.945e-01. Step accepted
# Iter:   75, time: 3.904e+00, f:  3.308e+01, |g|: 1.565e+00, |M^{-1}g|: 5.061e+01, Delta: 5.170e-01, inner iters:    38, |h|: 2.260e+01, |h|_M: 5.170e-01, df:  1.183e-01, rho:  7.656e-01. Step accepted
# Iter:   76, time: 3.972e+00, f:  3.296e+01, |g|: 3.538e+00, |M^{-1}g|: 4.166e+02, Delta: 5.170e-01, inner iters:    36, |h|: 4.815e+00, |h|_M: 1.638e-01, df:  1.566e-01, rho:  1.015e+00. Step accepted
# ...
# Iter:  289, time: 2.995e+01, f:  2.649e+01, |g|: 1.570e-01, |M^{-1}g|: 9.378e+00, Delta: 1.415e-01, inner iters:   243, |h|: 6.429e+00, |h|_M: 1.415e-01, df:  1.366e-03, rho:  7.707e-01. Step accepted
# Iter:  290, time: 3.033e+01, f:  2.649e+01, |g|: 2.099e-01, |M^{-1}g|: 4.624e+01, Delta: 1.415e-01, inner iters:     9, |h|: 3.116e-02, |h|_M: 8.910e-04, df:  4.388e-04, rho:  1.000e+00. Step accepted
# Iter:  291, time: 3.034e+01, f:  2.649e+01, |g|: 4.689e-02, |M^{-1}g|: 3.029e+00, Delta: 1.415e-01, inner iters:   173, |h|: 6.680e+00, |h|_M: 1.415e-01, df:  5.614e-04, rho:  9.508e-01. Step accepted
# Iter:  292, time: 3.061e+01, f:  2.649e+01, |g|: 6.347e-02, |M^{-1}g|: 8.580e+00, Delta: 3.537e-01, inner iters:   271, |h|: 1.684e+01, |h|_M: 3.537e-01, df:  1.043e-03, rho:  8.033e-01. Step accepted
# Iter:  293, time: 3.102e+01, f:  2.648e+01, |g|: 1.971e-01, |M^{-1}g|: 2.993e+01, Delta: 3.537e-01, inner iters:    35, |h|: 2.430e-01, |h|_M: 9.669e-03, df:  6.363e-04, rho:  1.000e+00. Step accepted
# Iter:  294, time: 3.108e+01, f:  2.648e+01, |g|: 4.454e-02, |M^{-1}g|: 2.102e+00, Delta: 3.537e-01, inner iters:   316, |h|: 1.682e+01, |h|_M: 3.537e-01, df:  1.048e-03, rho:  7.488e-01. Step accepted
# Iter:  295, time: 3.155e+01, f:  2.648e+01, |g|: 1.714e-01, |M^{-1}g|: 2.959e+01, Delta: 3.537e-01, inner iters:    14, |h|: 6.992e-02, |h|_M: 1.761e-03, df:  3.751e-04, rho:  1.000e+00. Step accepted
# Iter:  296, time: 3.157e+01, f:  2.648e+01, |g|: 5.221e-02, |M^{-1}g|: 2.103e+00, Delta: 3.537e-01, inner iters:   355, |h|: 1.678e+01, |h|_M: 3.537e-01, df:  9.064e-04, rho:  6.292e-01. Step accepted
# Iter:  297, time: 3.210e+01, f:  2.648e+01, |g|: 2.470e-01, |M^{-1}g|: 6.745e+01, Delta: 3.537e-01, inner iters:    10, |h|: 5.233e-02, |h|_M: 1.388e-03, df:  5.347e-04, rho:  1.000e+00. Step accepted
# Iter:  298, time: 3.212e+01, f:  2.648e+01, |g|: 9.139e-02, |M^{-1}g|: 3.759e+00, Delta: 3.537e-01, inner iters:   398, |h|: 1.679e+01, |h|_M: 3.537e-01, df:  4.977e-04, rho:  3.861e-01. Step accepted
# Iter:  299, time: 3.272e+01, f:  2.648e+01, |g|: 2.359e-01, |M^{-1}g|: 5.373e+01, Delta: 3.537e-01, inner iters:    13, |h|: 8.610e-02, |h|_M: 2.035e-03, df:  8.241e-04, rho:  1.000e+00. Step accepted
# Iter:  300, time: 3.274e+01, f:  2.648e+01, |g|: 7.264e-02, |M^{-1}g|: 2.799e+00, Delta: 3.537e-01, inner iters:   412, |h|: 1.676e+01, |h|_M: 3.537e-01, df:  4.483e-04, rho:  4.087e-01. Step accepted
# Iter:  301, time: 3.335e+01, f:  2.648e+01, |g|: 2.760e-01, |M^{-1}g|: 9.048e+01, Delta: 3.537e-01, inner iters:     9, |h|: 4.904e-02, |h|_M: 1.303e-03, df:  6.259e-04, rho:  1.000e+00. Step accepted
# Iter:  302, time: 3.337e+01, f:  2.648e+01, |g|: 9.499e-02, |M^{-1}g|: 5.201e+00, Delta: 3.537e-01, inner iters:   440, |h|: 1.678e+01, |h|_M: 3.537e-01, df:  3.361e-04, rho:  3.446e-01. Step accepted
# Iter:  303, time: 3.405e+01, f:  2.648e+01, |g|: 2.365e-01, |M^{-1}g|: 5.189e+01, Delta: 3.537e-01, inner iters:    13, |h|: 8.148e-02, |h|_M: 1.901e-03, df:  7.037e-04, rho:  1.000e+00. Step accepted
# Iter:  304, time: 3.408e+01, f:  2.648e+01, |g|: 7.118e-02, |M^{-1}g|: 2.583e+00, Delta: 3.537e-01, inner iters:   465, |h|: 1.680e+01, |h|_M: 3.537e-01, df:  3.100e-04, rho:  4.017e-01. Step accepted
# Iter:  305, time: 3.477e+01, f:  2.648e+01, |g|: 2.093e-01, |M^{-1}g|: 6.753e+01, Delta: 3.537e-01, inner iters:     9, |h|: 5.260e-02, |h|_M: 1.269e-03, df:  4.268e-04, rho:  1.000e+00. Step accepted
# Iter:  306, time: 3.478e+01, f:  2.648e+01, |g|: 6.669e-02, |M^{-1}g|: 3.828e+00, Delta: 3.537e-01, inner iters:   298, |h|: 3.724e+00, |h|_M: 8.188e-02, df:  3.683e-04, rho:  9.973e-01. Step accepted
# Iter:  307, time: 3.523e+01, f:  2.648e+01, |g|: 2.146e-02, |M^{-1}g|: 4.452e+00, Delta: 3.537e-01, inner iters:    28, |h|: 2.576e-02, |h|_M: 9.116e-04, df:  8.224e-06, rho:  1.000e+00. Step accepted
#
# Optimization finished!
# Algorithm terminated due to insufficient relative decrease: 3.106e-07 < 1.000e-06
# Final objective value: 2.648e+01
# Norm of Riemannian gradient: 2.146e-02
# Norm of preconditioned Riemannian gradient: 4.452e+00
# Total elapsed computation time: 3.528e+01 seconds
#
#
# Found first-order critical point with value F(Y) = 26.4763!  Elapsed computation time: 35.278 seconds
#
# Checking second order optimality ...
# Saddle point detected! Curvature along escape direction: -0.00207042.  Elapsed computation time: 0.073 seconds (1 LOBPCG iterations).
#
#
# ====== RIEMANNIAN STAIRCASE (level r = 5) ======
#
# Truncated-Newton trust-region optimization:
#
# Iter:    0, time: 0.000e+00, f:  2.646e+01, |g|: 2.367e+00, |M^{-1}g|: 6.875e+01, Delta: 1.000e+00, inner iters:    11, |h|: 3.315e+01, |h|_M: 1.000e+00, df: -1.770e+01, rho: -5.859e+00. Step REJECTED!
# Iter:    1, time: 3.000e-02, f:  2.646e+01, |g|: 2.367e+00, |M^{-1}g|: 6.875e+01, Delta: 2.500e-01, inner iters:    10, |h|: 8.137e+00, |h|_M: 2.500e-01, df:  1.139e-01, rho:  3.570e-01. Step accepted
# Iter:    2, time: 6.000e-02, f:  2.635e+01, |g|: 1.986e+01, |M^{-1}g|: 1.064e+03, Delta: 2.500e-01, inner iters:     7, |h|: 7.187e+00, |h|_M: 2.500e-01, df:  4.370e+00, rho:  9.184e-01. Step accepted
# Iter:    3, time: 9.000e-02, f:  2.198e+01, |g|: 2.225e+01, |M^{-1}g|: 1.691e+03, Delta: 6.250e-01, inner iters:     9, |h|: 1.883e+01, |h|_M: 6.250e-01, df:  5.308e+00, rho:  3.792e-01. Step accepted
# Iter:    4, time: 1.260e-01, f:  1.667e+01, |g|: 5.023e+01, |M^{-1}g|: 1.623e+03, Delta: 6.250e-01, inner iters:    16, |h|: 1.030e+01, |h|_M: 6.250e-01, df:  8.614e+00, rho:  9.272e-01. Step accepted
# Iter:    5, time: 1.740e-01, f:  8.058e+00, |g|: 3.307e+01, |M^{-1}g|: 1.934e+03, Delta: 1.562e+00, inner iters:    26, |h|: 2.117e+01, |h|_M: 1.562e+00, df:  3.838e+00, rho:  6.492e-01. Step accepted
# Iter:    6, time: 2.420e-01, f:  4.221e+00, |g|: 2.280e+01, |M^{-1}g|: 1.089e+03, Delta: 1.562e+00, inner iters:    48, |h|: 1.701e+01, |h|_M: 1.562e+00, df: -1.035e+00, rho: -2.948e-01. Step REJECTED!
# Iter:    7, time: 3.580e-01, f:  4.221e+00, |g|: 2.280e+01, |M^{-1}g|: 1.089e+03, Delta: 3.906e-01, inner iters:    27, |h|: 1.903e+00, |h|_M: 3.906e-01, df:  2.106e+00, rho:  9.999e-01. Step accepted
# Iter:    8, time: 4.280e-01, f:  2.115e+00, |g|: 1.213e+01, |M^{-1}g|: 2.040e+02, Delta: 9.766e-01, inner iters:    83, |h|: 1.614e+01, |h|_M: 9.766e-01, df:  3.237e-01, rho:  3.836e-01. Step accepted
# Iter:    9, time: 6.240e-01, f:  1.791e+00, |g|: 8.630e+00, |M^{-1}g|: 7.363e+02, Delta: 9.766e-01, inner iters:    17, |h|: 5.277e-01, |h|_M: 6.398e-02, df:  3.779e-01, rho:  1.001e+00. Step accepted
# Iter:   10, time: 6.680e-01, f:  1.413e+00, |g|: 3.019e+00, |M^{-1}g|: 3.550e+01, Delta: 9.766e-01, inner iters:   113, |h|: 3.770e+01, |h|_M: 9.766e-01, df: -2.051e+01, rho: -1.248e+02. Step REJECTED!
# Iter:   11, time: 9.270e-01, f:  1.413e+00, |g|: 3.019e+00, |M^{-1}g|: 3.550e+01, Delta: 2.441e-01, inner iters:    46, |h|: 3.880e+00, |h|_M: 2.441e-01, df:  9.090e-02, rho:  9.459e-01. Step accepted
# Iter:   12, time: 1.038e+00, f:  1.323e+00, |g|: 1.267e+00, |M^{-1}g|: 9.283e+01, Delta: 6.104e-01, inner iters:    64, |h|: 2.290e+01, |h|_M: 6.104e-01, df: -3.754e+00, rho: -7.109e+01. Step REJECTED!
# Iter:   13, time: 1.189e+00, f:  1.323e+00, |g|: 1.267e+00, |M^{-1}g|: 9.283e+01, Delta: 1.526e-01, inner iters:    54, |h|: 5.320e+00, |h|_M: 1.526e-01, df:  1.271e-02, rho:  5.619e-01. Step accepted
# Iter:   14, time: 1.321e+00, f:  1.310e+00, |g|: 1.288e+00, |M^{-1}g|: 1.855e+02, Delta: 1.526e-01, inner iters:    17, |h|: 1.507e-01, |h|_M: 1.198e-02, df:  1.014e-02, rho:  9.995e-01. Step accepted
# Iter:   15, time: 1.364e+00, f:  1.300e+00, |g|: 4.745e-01, |M^{-1}g|: 8.500e+00, Delta: 1.526e-01, inner iters:    59, |h|: 6.128e+00, |h|_M: 1.526e-01, df: -1.238e-03, rho: -1.234e-01. Step REJECTED!
# Iter:   16, time: 1.501e+00, f:  1.300e+00, |g|: 4.745e-01, |M^{-1}g|: 8.500e+00, Delta: 3.815e-02, inner iters:    28, |h|: 1.106e+00, |h|_M: 3.815e-02, df:  3.705e-03, rho:  1.012e+00. Step accepted
# Iter:   17, time: 1.571e+00, f:  1.296e+00, |g|: 3.735e-01, |M^{-1}g|: 1.463e+01, Delta: 9.537e-02, inner iters:    35, |h|: 3.979e+00, |h|_M: 9.537e-02, df:  3.833e-03, rho:  7.012e-01. Step accepted
# Iter:   18, time: 1.656e+00, f:  1.292e+00, |g|: 7.663e-01, |M^{-1}g|: 7.316e+01, Delta: 9.537e-02, inner iters:    23, |h|: 2.660e-01, |h|_M: 1.423e-02, df:  4.064e-03, rho:  9.987e-01. Step accepted
# Iter:   19, time: 1.713e+00, f:  1.288e+00, |g|: 2.313e-01, |M^{-1}g|: 5.670e+00, Delta: 9.537e-02, inner iters:    35, |h|: 4.094e+00, |h|_M: 9.537e-02, df:  3.655e-03, rho:  8.991e-01. Step accepted
# Iter:   20, time: 1.798e+00, f:  1.284e+00, |g|: 6.045e-01, |M^{-1}g|: 4.359e+01, Delta: 9.537e-02, inner iters:    54, |h|: 3.848e+00, |h|_M: 9.537e-02, df:  3.771e-03, rho:  6.582e-01. Step accepted
# Iter:   21, time: 1.928e+00, f:  1.281e+00, |g|: 6.483e-01, |M^{-1}g|: 5.725e+01, Delta: 9.537e-02, inner iters:    30, |h|: 4.171e-01, |h|_M: 2.308e-02, df:  3.233e-03, rho:  9.964e-01. Step accepted
# Iter:   22, time: 2.003e+00, f:  1.277e+00, |g|: 2.315e-01, |M^{-1}g|: 3.805e+00, Delta: 9.537e-02, inner iters:    47, |h|: 4.066e+00, |h|_M: 9.537e-02, df:  2.199e-03, rho:  7.667e-01. Step accepted
# Iter:   23, time: 2.117e+00, f:  1.275e+00, |g|: 5.331e-01, |M^{-1}g|: 4.117e+01, Delta: 9.537e-02, inner iters:    64, |h|: 3.477e+00, |h|_M: 9.537e-02, df: -1.368e-03, rho: -3.268e-01. Step REJECTED!
# Iter:   24, time: 2.296e+00, f:  1.275e+00, |g|: 5.331e-01, |M^{-1}g|: 4.117e+01, Delta: 2.384e-02, inner iters:    35, |h|: 5.619e-01, |h|_M: 2.384e-02, df:  2.077e-03, rho:  9.746e-01. Step accepted
# Iter:   25, time: 2.386e+00, f:  1.273e+00, |g|: 2.034e-01, |M^{-1}g|: 7.273e+00, Delta: 5.960e-02, inner iters:    46, |h|: 2.533e+00, |h|_M: 5.960e-02, df:  1.434e-03, rho:  9.688e-01. Step accepted
# Iter:   26, time: 2.508e+00, f:  1.272e+00, |g|: 3.404e-01, |M^{-1}g|: 1.958e+01, Delta: 1.490e-01, inner iters:    81, |h|: 6.567e+00, |h|_M: 1.490e-01, df: -2.460e-03, rho: -7.703e-01. Step REJECTED!
# Iter:   27, time: 2.717e+00, f:  1.272e+00, |g|: 3.404e-01, |M^{-1}g|: 1.958e+01, Delta: 3.725e-02, inner iters:    52, |h|: 1.406e+00, |h|_M: 3.725e-02, df:  1.262e-03, rho:  9.568e-01. Step accepted
# Iter:   28, time: 2.856e+00, f:  1.270e+00, |g|: 2.217e-01, |M^{-1}g|: 7.624e+00, Delta: 9.313e-02, inner iters:    62, |h|: 4.216e+00, |h|_M: 9.313e-02, df:  1.396e-03, rho:  8.000e-01. Step accepted
# Iter:   29, time: 3.017e+00, f:  1.269e+00, |g|: 3.956e-01, |M^{-1}g|: 2.371e+01, Delta: 9.313e-02, inner iters:    34, |h|: 1.818e-01, |h|_M: 1.084e-02, df:  9.630e-04, rho:  9.982e-01. Step accepted
# Iter:   30, time: 3.114e+00, f:  1.268e+00, |g|: 1.133e-01, |M^{-1}g|: 1.812e+00, Delta: 9.313e-02, inner iters:    79, |h|: 4.244e+00, |h|_M: 9.313e-02, df:  8.573e-04, rho:  7.729e-01. Step accepted
# Iter:   31, time: 3.305e+00, f:  1.267e+00, |g|: 3.036e-01, |M^{-1}g|: 4.187e+01, Delta: 9.313e-02, inner iters:    17, |h|: 2.927e-02, |h|_M: 2.976e-03, df:  4.406e-04, rho:  1.000e+00. Step accepted
# Iter:   32, time: 3.351e+00, f:  1.267e+00, |g|: 1.748e-01, |M^{-1}g|: 2.116e+00, Delta: 9.313e-02, inner iters:   101, |h|: 4.316e+00, |h|_M: 9.313e-02, df:  9.109e-04, rho:  9.500e-01. Step accepted
# Iter:   33, time: 3.560e+00, f:  1.266e+00, |g|: 2.486e-01, |M^{-1}g|: 1.590e+01, Delta: 2.328e-01, inner iters:    30, |h|: 6.791e-02, |h|_M: 6.013e-03, df:  3.504e-04, rho:  9.996e-01. Step accepted
# Iter:   34, time: 3.627e+00, f:  1.266e+00, |g|: 7.713e-02, |M^{-1}g|: 1.063e+00, Delta: 2.328e-01, inner iters:   121, |h|: 1.114e+01, |h|_M: 2.328e-01, df:  9.533e-04, rho:  8.117e-01. Step accepted
# Iter:   35, time: 3.882e+00, f:  1.265e+00, |g|: 2.201e-01, |M^{-1}g|: 4.873e+01, Delta: 2.328e-01, inner iters:     8, |h|: 1.382e-02, |h|_M: 5.311e-04, df:  2.210e-04, rho:  1.000e+00. Step accepted
# Iter:   36, time: 3.903e+00, f:  1.264e+00, |g|: 1.199e-01, |M^{-1}g|: 3.532e+00, Delta: 2.328e-01, inner iters:   371, |h|: 1.118e+01, |h|_M: 2.328e-01, df:  6.423e-04, rho:  8.923e-01. Step accepted
# Iter:   37, time: 4.686e+00, f:  1.264e+00, |g|: 9.281e-02, |M^{-1}g|: 1.861e+01, Delta: 2.328e-01, inner iters:    10, |h|: 2.633e-02, |h|_M: 6.111e-04, df:  9.497e-05, rho:  1.000e+00. Step accepted
# Iter:   38, time: 4.711e+00, f:  1.264e+00, |g|: 3.892e-02, |M^{-1}g|: 1.062e+00, Delta: 2.328e-01, inner iters:   444, |h|: 1.122e+01, |h|_M: 2.328e-01, df:  2.114e-04, rho:  6.559e-01. Step accepted
# Iter:   39, time: 5.653e+00, f:  1.263e+00, |g|: 1.152e-01, |M^{-1}g|: 5.499e+01, Delta: 2.328e-01, inner iters:     7, |h|: 2.539e-02, |h|_M: 5.766e-04, df:  1.073e-04, rho:  1.000e+00. Step accepted
# Iter:   40, time: 5.672e+00, f:  1.263e+00, |g|: 4.893e-02, |M^{-1}g|: 2.677e+00, Delta: 2.328e-01, inner iters:   517, |h|: 1.122e+01, |h|_M: 2.328e-01, df:  1.925e-04, rho:  6.420e-01. Step accepted
# Iter:   41, time: 6.920e+00, f:  1.263e+00, |g|: 1.020e-01, |M^{-1}g|: 4.787e+01, Delta: 2.328e-01, inner iters:     7, |h|: 2.399e-02, |h|_M: 5.549e-04, df:  1.065e-04, rho:  1.000e+00. Step accepted
# Iter:   42, time: 6.940e+00, f:  1.263e+00, |g|: 3.807e-02, |M^{-1}g|: 2.892e+00, Delta: 2.328e-01, inner iters:   395, |h|: 3.832e+00, |h|_M: 8.005e-02, df:  1.377e-04, rho:  9.873e-01. Step accepted
# Iter:   43, time: 7.828e+00, f:  1.263e+00, |g|: 2.720e-02, |M^{-1}g|: 1.221e+01, Delta: 2.328e-01, inner iters:     7, |h|: 2.303e-03, |h|_M: 6.308e-05, df:  3.249e-06, rho:  1.000e+00. Step accepted
# Iter:   44, time: 7.849e+00, f:  1.263e+00, |g|: 1.473e-02, |M^{-1}g|: 7.236e-01, Delta: 2.328e-01, inner iters:   495, |h|: 1.124e+01, |h|_M: 2.328e-01, df: -6.758e-05, rho: -4.772e-01. Step REJECTED!
# Iter:   45, time: 9.116e+00, f:  1.263e+00, |g|: 1.473e-02, |M^{-1}g|: 7.236e-01, Delta: 5.821e-02, inner iters:   277, |h|: 2.795e+00, |h|_M: 5.821e-02, df:  4.633e-05, rho:  9.999e-01. Step accepted
# Iter:   46, time: 9.718e+00, f:  1.263e+00, |g|: 1.472e-02, |M^{-1}g|: 1.049e+00, Delta: 1.455e-01, inner iters:   448, |h|: 7.017e+00, |h|_M: 1.455e-01, df:  6.897e-05, rho:  7.576e-01. Step accepted
# Iter:   47, time: 1.079e+01, f:  1.263e+00, |g|: 6.260e-02, |M^{-1}g|: 3.384e+01, Delta: 1.455e-01, inner iters:     6, |h|: 8.212e-03, |h|_M: 1.939e-04, df:  2.259e-05, rho:  1.000e+00. Step accepted
# Iter:   48, time: 1.081e+01, f:  1.263e+00, |g|: 2.112e-02, |M^{-1}g|: 1.432e+00, Delta: 1.455e-01, inner iters:   557, |h|: 7.016e+00, |h|_M: 1.455e-01, df:  8.645e-05, rho:  8.513e-01. Step accepted
# Iter:   49, time: 1.212e+01, f:  1.263e+00, |g|: 5.385e-02, |M^{-1}g|: 2.785e+01, Delta: 1.455e-01, inner iters:     6, |h|: 7.863e-03, |h|_M: 1.850e-04, df:  1.757e-05, rho:  1.000e+00. Step accepted
# Iter:   50, time: 1.214e+01, f:  1.263e+00, |g|: 2.236e-02, |M^{-1}g|: 1.851e+00, Delta: 1.455e-01, inner iters:   226, |h|: 8.995e-01, |h|_M: 1.931e-02, df:  3.046e-05, rho:  9.934e-01. Step accepted
# Iter:   51, time: 1.268e+01, f:  1.263e+00, |g|: 7.468e-03, |M^{-1}g|: 7.312e-01
#
# Optimization finished!
# Found first-order critical point! (Gradient norm: 7.468e-03)
# Final objective value: 1.263e+00
# Norm of Riemannian gradient: 7.468e-03
# Norm of preconditioned Riemannian gradient: 7.312e-01
# Total elapsed computation time: 1.268e+01 seconds
#
#
# Found first-order critical point with value F(Y) = 1.26259!  Elapsed computation time: 12.678 seconds
#
# Checking second order optimality ...
# Found second-order critical point! Elapsed computation time: 0.011 seconds.
#
#
# ===== END RIEMANNIAN STAIRCASE =====
#
# Found global optimum!
#
# Rounding solution ... elapsed computation time: 0.001 seconds
#
# SDP RESULTS:
# Value of dual SDP solution F(Y): 1.26259
# Norm of Riemannian gradient grad F(Y): 0.00746823
# Value of primal SDP solution tr(Lambda): 1.24707
# SDP duality gap: 0.0155268
#
# SE-SYNCHRONIZATION RESULTS:
# Value of rounded pose estimates F(x): 1.26361
# Suboptimality bound F(x) - tr(Lambda) of recovered pose estimate: 0.0165446
#
# Total elapsed computation time: 71.285 seconds
#
# ===== END SE-SYNC =====

# %% [markdown]
# ## Plot some interesting data about the solution process

# %% [markdown]
# Plot the sequence of gradient norms

# %%
# Plot sequence of Riemannian gradient norms
fig, ax = plt.subplots()
# Extract sequences of gradient and preconditioned gradient norms
grad_norms = np.concatenate(result.gradient_norms)
precon_grad_norms = np.concatenate(result.preconditioned_gradient_norms)

# Plot these sequences
plt.semilogy(grad_norms, '-b')
plt.semilogy(precon_grad_norms, '--c')
plt.legend(['Gradient', 'Preconditioned gradient'])

# Set the following flag to "True" in order to draw red vertical 
# lines indicating iterations at which the relaxation rank 
# increased in the Riemannian Staircase
show_rank_increases = True

if show_rank_increases and len(result.gradient_norms) > 1:
    steps = np.cumsum([len(l) for l in result.gradient_norms[:-1]])
    for i in steps:
        plt.axvline(x=i, ymin=0, ymax=np.log10(grad_norms.max()), color='red', linestyle='--')

plt.title("Gradient norms")
plt.xlabel("Iteration")

plt.show()
# Out:
# <div id='f0673c41-be88-4519-bb4e-4038906e2d9d'></div>

# %% [markdown]
# Plot the sequence of update step sizes

# %%
# Plot sequence of update step norms
fig, ax = plt.subplots()
# Extract sequences of gradient and preconditioned gradient norms
update_step_norms = np.concatenate(result.update_step_norms)
update_step_M_norms = np.concatenate(result.update_step_M_norms)

# Plot these sequences
plt.semilogy(update_step_norms, '-b')
plt.semilogy(update_step_M_norms, '--c')
plt.legend(['Frobenius norm', 'M norm'])

# Set the following flag to "True" in order to draw red vertical 
# lines indicating iterations at which the relaxation rank 
# increased in the Riemannian Staircase
show_rank_increases = True

if show_rank_increases and len(result.gradient_norms) > 1:
    steps = np.cumsum([len(l) for l in result.gradient_norms[:-1]])
    for i in steps:
        plt.axvline(x=i, ymin=0, ymax=np.log10(grad_norms.max()), color='red', linestyle='--')

plt.title("Update step norms")
plt.xlabel("Iteration")

plt.show()
# Out:
# <div id='51d4d5a9-f37d-463d-bcfc-fb8e8c84978e'></div>

# %% [markdown]
# Plot the sequence of gain ratios for the computed update steps

# %%
# Plot sequence of gain ratio values: this measures how well the second-order local model
# of the objective used to calculate the update steps h agrees with the *actual* objective F.
#
# This value should be close to 1 if the local model is accurately capturing the shape of the objective F over
# a region of the same size as the length of the update steps h
#
# Blue markers indicate iterations for which the gain ratio is positive (corresponding to accepted steps),
# while red markers indicate iterations for which the gain ratio is negative (corresponding to rejected steps)

fig, ax = plt.subplots()
gain_ratios = np.concatenate(result.gain_ratios)

# Plot sequence of nonnegative gain ratios with blue markers
nonnegative_rho_indicators = (gain_ratios >= 0)
nonnegative_rho_indxs = np.nonzero(nonnegative_rho_indicators)[0]
plt.plot(nonnegative_rho_indxs, gain_ratios[nonnegative_rho_indicators], \
         color='blue', marker=".", linestyle='None')

# Extract the set of iterations in which the gain ratio is less than 0;
# these correspond to iterations in which the proposed update was rejected
neg_rho_idxs = np.nonzero(gain_ratios < 0)[0]
num_neg_rhos = len(neg_rho_idxs)

# Plot these rejected steps
plt.plot(neg_rho_idxs, np.zeros(len(neg_rho_idxs)), color='red', marker='.', linestyle="None")

# Set reasonable range for viewing gain ratios
ax.set_ylim(-.1, 1.1)

# Set the following flag to "True" in order to draw red vertical 
# lines indicating iterations at which the relaxation rank 
# increased in the Riemannian Staircase
show_rank_increases = True

if show_rank_increases and len(result.function_values) > 1:
    steps = np.cumsum([len(l) for l in result.function_values[:-1]])
    for i in steps:
        plt.axvline(x=i, ymin=-2, ymax=2, color='red', linestyle='--')


plt.title("Gain ratios")
plt.xlabel("Iteration")
plt.show()
# Out:
# <div id='cd7cc782-e0cf-4114-86dc-c845219da85d'></div>

# %%
# Plot sequence of objective values
fig, ax = plt.subplots()
fvals = np.concatenate(result.function_values)
plt.semilogy(fvals)

# Set the following flag to "True" in order to draw red vertical 
# lines indicating iterations at which the relaxation rank 
# increased in the Riemannian Staircase
show_rank_increases = True

if show_rank_increases and len(result.function_values) > 1:
    steps = np.cumsum([len(l) for l in result.function_values[:-1]])
    for i in steps:
        plt.axvline(x=i, ymin=0, ymax=np.log10(fvals.max()), color='red', linestyle='--')


plt.title("Objective value")
plt.xlabel("Iteration")
plt.show()
# Out:
# <div id='ef2f9383-c80f-47cf-82ca-1c4eaa86bdeb'></div>

# %% [markdown]
# ### Plot estimated SLAM solution

# %% [markdown]
# Define some useful functions for visualizing SLAM solution

# %%
# Given a list of position estimates and a collection of measurements, this function constructs a list of
# pairs of the form (ti, tj), where ti and tj are the endpoints of a relative pose measurement
def construct_line_segments(t, measurements):
    lines = []
    
    for m in measurements:
        lines.append((t[:,m.i], t[:,m.j]))
    
    return lines

# Given an SESyncProblem instance, a low-rank factor Y for an estimated SDP solution X = YY', this function
# returns the rounded (projected) position estimates t
def get_rounded_position_estimates(prob, Y):
    # Get problem dimensions
    d = prob.dimension()
    n = prob.num_states()
    
    # Get relaxtion rank for the passed estimate Y
    r = Y.shape[0]
    
    # Compute rounded pose estimates
    xhat = prob.round_solution(Y)
    
    # Extract rotational and translational parts
    R0 = xhat[:, n : n + d]
    R0inv = R0.transpose()
    return np.matmul(R0inv, xhat[:, 0:n])

# %% [markdown]
# Plot the final SLAM estimate

# %%
# Extract translational states from solution xhat
xhat = result.xhat
R0inv = np.linalg.inv(xhat[:, num_poses : num_poses + d])
t = np.matmul(R0inv, xhat[:, 0:num_poses])

# Construct set of inter-pose measurements at the estimated robot positions
lines = construct_line_segments(t, measurements)

# Determine dimension of problem

# Plot the estimated solution
fig = plt.figure()

if d == 2:
    ax = plt.gca()
    ax.set_xlim(t[0, :].min(), t[0, :].max())
    ax.set_ylim(t[1, :].min(), t[1, :].max())
    ax.set_xlabel("x [m]")
    ax.set_ylabel("y [m]")
    
    lc = mc.LineCollection(lines)
    ax.add_collection(lc)
    ax.set_aspect('equal')

else:
    # d == 3
    ax = fig.add_subplot(projection='3d')
    ax.set_xlim(t[0, :].min(), t[0, :].max())
    ax.set_ylim(t[1, :].min(), t[1, :].max())
    ax.set_zlim(t[2, :].min(), t[2, :].max())
    ax.set_xlabel("x [m]")
    ax.set_ylabel("y [m]")
    ax.set_zlabel("z [m]")
    
    lc = Line3DCollection(lines)
    ax.add_collection3d(lc)
    ax.set_box_aspect((1,1,1))

plt.title("Estimated SLAM solution")
plt.show()
# Out:
# <div id='f988bf55-9188-4c0c-968a-f27f43705697'></div>

# %% [markdown]
# ### Generate a video of the solution process

# %% [markdown]
# Compute rounded position estimates for each iterate generated during the entire optimization

# %%
# Construct SE-Sync problem instance
prob = PySESync.SESyncProblem(measurements, opts.formulation, opts.projection_factorization, \
                              opts.preconditioner, opts.reg_Chol_precon_max_cond)

# Record maximum and minimum x- and y- values of each estimated position; we will use these later
# to set the figure axis ranges
xmax = -float('inf')
xmin = float('inf')
ymax = -float('inf')
ymin = float('inf')
zmax = -float('inf')
zmin = float('inf')


# Construct a list of line collections, one for each estimated (rounded) solution
solns = []
for Ys in result.iterates:
    for Y in Ys:
        # Get rounded position estimates
        t = get_rounded_position_estimates(prob, Y)
        
        # Update maximum and minimum x- and y- values
        xmax = max(xmax, t[0, :].max())
        xmin = min(xmin, t[0, :].min())
        ymax = max(ymax, t[1, :].max())
        ymin = min(ymin, t[1, :].min())
        
        if d == 3:
            # Also record zmax and zmin values
            zmax = max(zmax, t[2, :].max())
            zmin = min(zmin, t[2, :].min())

        # Calculate the set of segments for this solution
        solns.append(construct_line_segments(t, measurements))

# %% [markdown]
# Render visualization!

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()

if d == 2:
    # Construct set of 2D axes
    ax = plt.axes(xlim=(xmin, xmax), ylim=(ymin, ymax))
    ax.set_xlabel("x [m]")
    ax.set_ylabel("y [m]")
    ax.set_aspect('equal')

    # Initialize line collection and add it to the figure
    lc = mc.LineCollection([])
    ax.add_collection(lc)
    
else:
    # Construct set of 3D axes
    ax = fig.add_subplot(projection='3d')
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.set_zlim(zmin, zmax)
    ax.set_xlabel("x [m]")
    ax.set_ylabel("y [m]")
    ax.set_zlabel("z [m]")
    ax.set_box_aspect((1,1,1))
    
    # Initialize line collection and add it to the figure
    lc = Line3DCollection([])
    ax.add_collection3d(lc)
    


# Initialization function: plot the background of each frame
def init():
    lc.set_segments([])
    return lc

# Animation function.  This is called sequentially
def update(i):
    lc.set_segments(solns[i])
    ax.set_title("Iteration %d" % i)
    return lc

# Call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, update, init_func=init, frames=len(solns), interval=67)

if save_animation:
    # Save this animation to disk
    writer = animation.FFMpegWriter(fps = 15, codec='ffv1')
    anim.save('SESync.avi', writer=writer)
